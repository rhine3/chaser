# %% [markdown]
# # Number of lines in file
#
# ```
# data_file = '/Volumes/seagate-storage/code/ebird_data/ebd_relJan-2019.txt'
# count = 0
# for line in open(data_file): count += 1
# ```
#
# After this, `count` = 577335302

# %% [markdown]
# # Figure out which columns to store

# %% [markdown]
# Save:
# * `LAST EDITED DATE`
# * `CATEGORY`
# * `COMMON NAME`
# * `OBSERVATION COUNT`
# * `COUNTY CODE`
# * `LATITUDE`
# * `LONGITUDE`
# * `OBSERVATION DATE`
# * `TIME OBSERVATIONS STARTED`
# * `OBSERVER ID`
# * `SAMPLING EVENT IDENTIFIER`
# * `PROTOCOL TYPE`
# * `DURATION MINUTES`
# * `NUMBER OBSERVERS`
# * `ALL SPECIES REPORTED`

# %%
# %%bash
# head -2 /Volumes/seagate-storage/code/ebird_data/ebd_relJan-2019.txt
# Out:
# GLOBAL UNIQUE IDENTIFIER	LAST EDITED DATE	TAXONOMIC ORDER	CATEGORY	COMMON NAME	SCIENTIFIC NAME	SUBSPECIES COMMON NAME	SUBSPECIES SCIENTIFIC NAME	OBSERVATION COUNT	BREEDING BIRD ATLAS CODE	BREEDING BIRD ATLAS CATEGORY	AGE/SEX	COUNTRY	COUNTRY CODE	STATE	STATE CODE	COUNTY	COUNTY CODE	IBA CODE	BCR CODE	USFWS CODE	ATLAS BLOCK	LOCALITY	LOCALITY ID	 LOCALITY TYPE	LATITUDE	LONGITUDE	OBSERVATION DATE	TIME OBSERVATIONS STARTED	OBSERVER ID	SAMPLING EVENT IDENTIFIER	PROTOCOL TYPE	PROTOCOL CODE	PROJECT CODE	DURATION MINUTES	EFFORT DISTANCE KM	EFFORT AREA HA	NUMBER OBSERVERS	ALL SPECIES REPORTED	GROUP IDENTIFIER	HAS MEDIA	APPROVED	REVIEWED	REASON	TRIP COMMENTS	SPECIES COMMENTS
# URN:CornellLabOfOrnithology:EBIRD:OBS34169564	2014-10-16 08:19:55	6171	species	Bonaparte's Gull	Chroicocephalus philadelphia			6				Canada	CA	Quebec	CA-QC	Nicolet-Yamaska	CA-QC-NY					Port St-François	L352699	P	46.2722222	-72.6111111	2006-10-14	10:00:00	obsr31597	S2495584	Traveling	P22	EBIRD_CAN	60	1		1	0		0	1	0		Terns are late!

# %% [markdown]
# In text format:
#
# ```
# GLOBAL UNIQUE IDENTIFIER	                    LAST EDITED DATE	        TAXONOMIC ORDER	    CATEGORY	    COMMON NAME	        SCIENTIFIC NAME	               SUBSPECIES COMMON NAME	SUBSPECIES SCIENTIFIC NAME	OBSERVATION COUNT	BREEDING BIRD ATLAS CODE	BREEDING BIRD ATLAS CATEGORY	AGE/SEX	COUNTRY	COUNTRY CODE	STATE	STATE CODE	COUNTY	            COUNTY CODE	IBA CODE	BCR CODE	USFWS CODE	ATLAS BLOCK	LOCALITY	        LOCALITY ID	LOCALITY TYPE	LATITUDE	LONGITUDE	OBSERVATION DATE	TIME OBSERVATIONS STARTED	OBSERVER ID	SAMPLING EVENT IDENTIFIER	PROTOCOL TYPE	PROTOCOL CODE	PROJECT CODE	DURATION MINUTES	EFFORT DISTANCE KM	EFFORT AREA HA	NUMBER OBSERVERS	ALL SPECIES REPORTED	GROUP IDENTIFIER	HAS MEDIA	APPROVED	REVIEWED	REASON	TRIP COMMENTS	SPECIES COMMENTS
# URN:CornellLabOfOrnithology:EBIRD:OBS34169564	2014-10-16 08:19:55	        6171	            species	        Bonaparte's Gull	Chroicocephalus philadelphia		                    	                        6	                	                        	                        	        Canada	CA	            Quebec	CA-QC	     Nicolet-Yamaska	CA-QC-NY		        	        	        	        Port St-François	L352699	    P	            46.2722222	-72.6111111	2006-10-14	         10:00:00	                obsr31597	S2495584	                Traveling	    P22	            EBIRD_CAN	    60	                1	                	            1	                0	                    	                0	        1	        0	        	    Terns are late!
# ```

# %% [markdown]
# # Store a small subset of text file

# %%
import pandas as pd
from time import time
from sqlalchemy import create_engine, MetaData
from sqlalchemy_utils import database_exists, create_database
from functools import wraps

# %% [markdown]
# ### List of columns for each type of database

# %%
desired_cols_comprehensive = [
    'LAST EDITED DATE', #For telling whether or not the observation was submitted in 2018
    'CATEGORY', #Species or no? (not sure how others are represented)
    'COMMON NAME', 
    'OBSERVATION COUNT', #Number of individuals seen--or X'd (not sure how represented)
    'STATE CODE', #Something like US-PA-AL. Not sure if every obs has a county...
    'LATITUDE',
    'LONGITUDE',
    'OBSERVATION DATE',
    'TIME OBSERVATIONS STARTED',
    'OBSERVER ID',
    'SAMPLING EVENT IDENTIFIER', #The checklist itself... Not sure if there are anything besides S_____ formatted labels, and what the difference is from global unique identifier (maybe the latter is for the single species obs)
    'PROTOCOL TYPE', #Traveling... or something else? Not sure what else is out there
    'DURATION MINUTES', #To see if it has both a start and end time
    'NUMBER OBSERVERS', #Not sure if each observer's list is counted as a separate observation, or if only the originally submitting observer's is included
    'ALL SPECIES REPORTED',
]

# A subset of desired_cols_comprehensive; pared down for speed
desired_cols_chaser = {
    'CATEGORY':'str', #Species or no? (not sure how others are represented)
    'COMMON NAME':'str',
    'OBSERVATION COUNT':'str', #Number of individuals seen--or X'd (not sure how represented)
    'STATE CODE':'str', #Something like US-PA-AL. Not sure if every obs has a county...
    'LATITUDE':'str',
    'LONGITUDE':'str',
    'OBSERVATION DATE':'str',
    'SAMPLING EVENT IDENTIFIER':'str', #The checklist itself... Not sure if there are anything besides S_____ formatted labels, and what the difference is from global unique identifier (maybe the latter is for the single species obs)
}

# %% [markdown]
# ### Variables for `pd.read_csv` call:

# %%
# File to read from & number of lines to read
#data_file = '/Volumes/seagate-storage/code/ebird_data/medium_dataset.txt']
large_data_file = '/Volumes/seagate-storage/code/ebird_data/ebd_relJan-2019.txt'
data_file = '/Volumes/seagate-storage/code/ebird_data/small_file.txt'
lines_to_use = 1000000

# Made data file using terminal instead of Python, but here's the code I used for smaller tests.
with open(large_data_file, 'r') as oldfile:
    with open(data_file, 'w') as newfile: #Overwrite old file
        for _ in range(lines_to_use):
            newfile.write(next(oldfile))

# Which columns to use
desired_cols = desired_cols_chaser
                          
# Of columns, which are dates?
date_cols = ['OBSERVATION DATE']

# %%
# Chunk size to read through data_file
chunk_size = 10000

# %% [markdown]
# ### Variables for `pd.to_sql` call:

# %%
# Desired path for SQLITE db; if does not exist, will be created
engine_path = "/Volumes/seagate-storage/db/ebird_small.db"

# Name of SQL table
table_name = 'ebird_small_20190328'

# %% [markdown]
# ### Other variables

# %%
# How many chunks to print after
X = 100

# %% [markdown]
# ### Finally, save to database:

# %%
def process_data(
    engine_path,
    data_path,
    desired_cols,
    date_cols,
    chunk_size,
    table_name,
    X,
    delete_old_table = True
):
    t0 = time()
    
    engine = create_engine('sqlite:///' + engine_path)
    # If database doesn't already exist, make a new engine
    if not database_exists(engine.url):
        create_database(engine.url)
    # Otherwise, make sure the engine is clear
    # Note that it's MUCH faster to delete this from filesystem directly
    elif delete_old_table:
        meta = MetaData(engine)
        meta.reflect() # Find all tables
        # Only drop the table we're trying to refill
        for tbl in reversed(meta.sorted_tables):
            if tbl.name == table_name:
                engine.execute(tbl.delete())
                print(f'Dropped table {table_name}')
        
    t1 = time()
    
    lines_saved_to_db = 0
    counter = 0

    for chunk in pd.read_csv(
        filepath_or_buffer = data_path, 
        sep = '\t',
        usecols = desired_cols.keys(),
        parse_dates = date_cols, 
        chunksize = chunk_size,
        dtype = desired_cols,
        na_values = ['X']
    ):

        chunk.to_sql(
            name = table_name,
            con = engine,
            if_exists = 'append'
        )

        # Print info every X iterations
        # i.e., every chunk_size * X lines
        lines_saved_to_db += chunk.shape[0]
        if (not counter % X):
            print(f"Iteration {counter}:")
            print(f"  Lines saved to DB: {lines_saved_to_db}") #Helpful for only saving year data
            print(f"  Minutes elapsed: {(time()-t1)/60}\n")
        counter += 1

    db_time = (time()-t1)/60
    total_time = (time()-t0)/60
    estimated_time = ((total_time-db_time) +  (577335302/lines_saved_to_db)*db_time)/60
    print(f"Total iterations: {counter}")
    print(f"Total lines saved to DB: {lines_saved_to_db}") #Helpful for only saving year data
    print(f"Minutes elapsed during DB functions: {db_time}")
    print(f"Total minutes elapsed: {total_time}")
    print(f"Estimated time for all lines: {estimated_time} hours")
    return engine
            
engine = process_data(
    engine_path,
    data_file,
    desired_cols,
    date_cols,
    chunk_size,
    table_name,
    X
)
# Out:
# Dropped table ebird_small_20190328
# Iteration 0:
#   Lines saved to DB: 10000
#   Minutes elapsed: 0.006281014283498128
#
# Total iterations: 100
# Total lines saved to DB: 999999
# Minutes elapsed during DB functions: 0.41043624877929685
# Total minutes elapsed: 0.4188800017038981
# Estimated time for all lines: 3.9494669392206614 hours

# %% [markdown]
# # Try chaser on subset

# %%
import csv
import pandas as pd
import numpy as np
from geopy.distance import vincenty
import datetime
import collections
import math

# %% [markdown]
# Done below:
# ```
# show_unique(series)
# identify_centers(df, radius_miles=5)
# select_loc_df(df, my_dict, center)
# select_date_df(df, month, day, interval=4)
# calculate_score(df)
# interval_without_year(date1, date2)
# analyze_data(
#     df,
#     lifelist_path,
#     month,
#     day,
#     radius_miles)
# def import_data(
#     engine_path,
#     table_name)
# ```

# %%
def show_unique(series):
    '''
    Return a list of the unique elements in a pandas series
    '''
    
    all_elements = list(series)
    seen = set()
    seen_add = seen.add
    unique_elements = [x for x in all_elements if not (x in seen or seen_add(x))]

    return unique_elements

# %%
def identify_centers(df, radius_miles = 5):
    '''
    Create a dictionary where the
        keys = centers,
        values = list of points within the desired radius
    '''
    
    # Create a list of all unique points to use for our centers
    all_points = show_unique(df['LOCATION'])
    centers = all_points #TODO: create a more efficient center-finding algo

    my_dict = {}
    centers = all_points
    for center in centers:
        close_points = []
        for point in all_points:
            try:
                distance = vincenty(center, point, miles=True)
            except ValueError: #ValueError: Vincenty formula failed to converge!
                distance = np.NaN
            if distance < radius_miles:
                close_points.append(point)

        my_dict[center] = close_points
        
    return my_dict

# %%
def select_loc_df(df, my_dict, center): 
    '''
    Select relevant sightings by location
    
    For a single center (key), return a DF with only:
    - sightings from locations in the desired radius (value) 
    - sightings from a desired date range
    
    Inputs:
        df: the full dataframe to select sightings from
        my_dict: the dictionary associating centers with lists
            of points within the radius
        center: the specific dictionary key to use
    
    '''

    # Select only locations corresponding to radius around the center
    return df[df['LOCATION'].isin(my_dict[center])]

# %%
def select_date_df(df, month, day, interval=4): 
    '''
    Select relevant sightings by date
    
    For a single center (key), return a DF with only sightings from a desired date range
    
    Inputs:
        df: the full dataframe to select sightings from
        month, day: the date to center a date range around
        interval: the number of days before & after the specified
            date to include sightings from
    
    '''
    
    # Select only locations within date range
    desired_date=datetime.date(2019, month, day) #2019 is a placeholder year

    df['INTERVAL'] = df['OBSERVATION DATE'].apply(interval_without_year, date2=desired_date)
    selected_sightings = df.loc[df['INTERVAL'] <= interval]
    
     
    return selected_sightings

# %%
def calculate_score_total_spp(df):
    '''
    Calculate score of DF based on # species
    
    Calculate score of a DF solely by how many
    unique species are in the 'COMMON NAME' column.
    
    Inputs:
        df: a dataframe with a column 'COMMON NAME'. This df should
        contain one column for each individual observation of a species.
        
    Returns: 
    '''
    
    # Create DF associating common name with count of lists
    #(to maintain compliance with other scoring functions)
    collapsed_df = df['COMMON NAME'].value_counts()
    
    # Calculate true score
    score = len(show_unique(df['COMMON NAME']))
    
    return score, collapsed_df

# %%
def calculate_score_num_lists(df):

    '''
    Calculate score of DF based on # lists
    
    Calculate the score of a DF by finding
    the number of checklists on which a species was reported.
    This could be modified to be more sophisticated in the future.
    
    Inputs:
        df: a dataframe with a column 'COMMON NAME'. This df should
            contain one column for each individual observation of a species.
    
    Outputs:
        the sum of the number of checklists each species
        appeared on--which is identical to df.shape[0]
    '''
    
    # Create DF associating common name with count of lists
    collapsed_df = df['COMMON NAME'].value_counts()
    
    # Calculate true score
    score = sum(collapsed_df)
    
    return score, collapsed_df

# %%
def interval_without_year(date1, date2):
    '''
    Return number of days between two dates
    
    Returns interval of days between two dates regardless of year. 
    For instance, January 1, 2019 and January 4, 1999 are considered 
    3 days apart with this method, no matter which one is provided
    as day1 or day2.
    
    This function may be imperfect WRT leap years.
    
    Inputs:
        date1, date2: datetime.date objects
        
    Returns:
        number of days between them on calendar (regardless of year)
    
    '''
    date1 = date1.date()
    delta = date1-date2
    way1 = delta.days % 365
    way2 = 365-way1
    
    if way1 < way2: return way1
    else: return way2

# %%
def analyze_data(
    df,
    lifelist_path,
    month,
    day,
    padding,
    radius_miles,
    scoring_method = 'total' #or 'lists'
):
    '''
    Find best area for a given month, day, and radius
    
    Inputs
        df: dataframe of eBird observations generated by import_data
        lifelist_path: path to .csv of life list file. Species should be in format:
            'Black-bellied Whistling-Duck - Dendrocygna autumnalis' (without quotes)
        month: numerical month of 'center date' around which to search for hotspots
        day: numerical day of 'center date' around which to search for hotspots
        padding: how many days before and after the 'center date' the observations should include
        radius_miles: how large of a radius do you want to search within
        scoring_method: how to score hotspots
            total: just based on the total number of species
            lists: based on how many lists each lifer appeared
        
    Returns (all_dfs, all_scores)
        all_dfs: a dataframe for every center
        all_scores: a score for every center
    '''
    
    # Generate list of lifers from .csv file
    life_list = []
    with open(lifelist_path) as f:
        reader = csv.reader(f)
        
        # Handle different eBird life list formats
        next(reader) # Skip line 0, the header
        test_bird = next(reader)[1]
        f.seek(1) # Go back to line 1, the first data row
        # For scientific names
        if ' - ' in test_bird:
            for line in reader:
                bird = ' '.join(line[1].split()[:-3])
                life_list.append(str(bird).lower()) 
                
        # For no scientific names:
        else:
            for line in reader:
                bird = line[1]
                life_list.append(str(bird).lower()) 
        
        

    # Remove species that are already on one's life list
    df = df[~df['COMMON NAME'].str.lower().isin(life_list)]
    
    
    # Remove checklists from outside of this date range
    df = select_date_df(df, month, day, interval=4)
    
    
    # Identify a dict of centers
    my_dict = identify_centers(df, radius_miles)
    
    
    # For each center, generate a relevant DF and calculate its score
    all_dfs = {}
    all_scores = {}
    for center in my_dict.keys():
        
        # Select only locations within radius
        selected_df = select_loc_df(df, my_dict, center)
        
        # Calculate score and 'collapsed DF', which is a dataframe
        # associating each species with the number of checklists it appeared on
        if scoring_method == 'lists':
            score, collapsed_df = calculate_score_num_lists(selected_df)
        else:
            score, collapsed_df = calculate_score_total_spp(selected_df)
        
        # Create dictionaries associating centers with their scores & collapsed dfs
        all_scores[center] = score
        all_dfs[center] = collapsed_df
        
    
    return (all_dfs, all_scores)

# %%
def import_data(
    engine_path,
    table_name,
):
    '''
    Import and clean dataset from database.
    
    Import a dataset from a database. Add a location column and remove
    extraneous records (spuhs, slashes, hybrids, domestics) from dataset.
    
    Inputs
        engine_path: path to db location, e.g. '/Volumes/storage/data.db'
        table_name: the name of the table in this database, e.g. 'usa_only'
        
    Returns
        a rough database
    '''
    
    # Import data
    engine = create_engine('sqlite:///' + engine_path)
    rough_df = pd.read_sql(table_name, con = engine)
    
    # Add location column
    rough_df['LOCATION'] = rough_df.apply(lambda row: (row['LATITUDE'], row['LONGITUDE']), axis=1)
    
    # Remove spuhs, slashes, domestics, and hybrids to leave only species, issf, and form
    return rough_df[~rough_df['CATEGORY'].isin(['spuh', 'domestic', 'slash', 'hybrid'])]

# %%
def chaser(
    engine_path,
    table_name,
    lifelist_filename,
    month,
    day,
    padding,
    num_spots,
    radius_miles,
    scoring_method = 'total' #or 'lists'
):
    
    '''
    Find the best places to go for your life list
    
    Inputs
        engine_path: path to database of all observations, e.g. '/Volumes/storage/all_data.db'
        table_name: name of relevant table within database, e.g. 'usa_only_table'
        lifelist_filename: path to .csv file containing a single column
            All species must be in format: 'Black-bellied Whistling-Duck - Dendrocygna autumnalis'
            To create a file like this, download your life list, then copy and paste the 'Species'
            column into a new .csv. Do not include the 'species' header (though it won't make a difference).
            Life list can be downloaded at https://ebird.org/MyEBird?cmd=lifeList&listType=world&listCategory=default&time=life
        month: numerical month in which to search for lifer spots
        day: numerical day around which to search for lifer spots
        padding: number of days before and after month/day to search for lifer spots
        num_spots: number of top spots to show
        radius_miles: miles within which you are willing to bird
    '''
    
    
    # Get DF of data
    my_df = import_data(engine_path, table_name)
    
    # Only look for places in the USA (#ABAcentrism)
    my_df = my_df[(my_df['STATE CODE'].str.contains('US-')) | (my_df['STATE CODE'].str.contains('CA-'))]

    # Get dict of dfs of highest-scoring spots
    dfs, scores = analyze_data(
        df = my_df,
        lifelist_path = lifelist_filename, 
        month = month,
        day = day,
        padding = padding,
        radius_miles = radius_miles,
        scoring_method = scoring_method)


    # Sort by scores
    #sorted_d = sorted(((value, key) for (key,value) in scores.items()), reverse=True)
    
    # Sort by number of targets
    sorted_d = sorted(((value, key) for (key,value) in scores.items()), reverse=True)

    if len(sorted_d) < num_spots:
        num_to_show = len(sorted_d)
    else:
        num_to_show = num_spots

    for i in range(num_to_show):
        center =  sorted_d[i][1]

        # Identify most common targets
        center_df = dfs[center]
        top_10percent = math.ceil(.1 * center_df.size)
        targets = list(center_df.reset_index()['index'][0:])

        print('Top spot {}:'.format(i+1), center)
        print('Number possible targets:', len(targets))
        print('Most common targets:', targets)
        print('')
    
    return scores

# %% [markdown]
# # Washington yearlist, J

# %%
engine_path = "/Volumes/seagate-storage/db/ebird_small.db"
table_name = 'ebird_small_20190328'
lifelist_filename = 'josh-yearlist.csv'
month = 3
day = 29
padding = 2
num_spots = 5
radius_miles = 100

josh_scores_all = chaser(
    engine_path,
    table_name,
    lifelist_filename,
    month,
    day,
    padding,
    num_spots,
    radius_miles
)

josh_scores_all
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
# Top spot 1: ('27.0446212', '-99.4444013')
# Number possible targets: 79
# Most common targets: ['Chihuahuan Raven', 'Northern Cardinal', 'Great Kiskadee', 'Northern Mockingbird', 'Scissor-tailed Flycatcher', 'Golden-fronted Woodpecker', 'Altamira Oriole', 'Black-crested Titmouse', 'Great-tailed Grackle', 'Loggerhead Shrike', 'Lark Sparrow', 'Inca Dove', "Harris's Hawk", 'Laughing Gull', 'White-tipped Dove', "Audubon's Oriole", 'Plain Chachalaca', "Couch's Kingbird", 'Common Ground-Dove', 'Red-billed Pigeon', 'Cedar Waxwing', 'Spotted Sandpiper', 'Crested Caracara', 'Northern Rough-winged Swallow', 'Green Kingfisher', 'Purple Martin', 'Chimney Swift', 'Mottled Duck', 'Blue-gray Gnatcatcher', 'Brown-headed Cowbird', "Swainson's Hawk", 'Ringed Kingfisher', 'Barn Swallow', 'Cliff Swallow', 'Neotropic Cormorant', 'White-winged Dove', 'Curve-billed Thrasher', 'Common Yellowthroat', "Lincoln's Sparrow", 'Ladder-backed Woodpecker', 'Broad-winged Hawk', 'Lesser Nighthawk', 'Greater Roadrunner', 'Cinnamon Teal', 'Hooded Oriole', 'Black-chinned Hummingbird', 'Bank Swallow', 'Swamp Sparrow', 'Anhinga', 'Bronzed Cowbird', 'Red-shouldered Hawk', 'Caspian Tern', 'American Avocet', 'Green Heron', "Wilson's Snipe", 'Clay-colored Sparrow', 'Black-crowned Night-Heron', 'Olive Sparrow', "Bullock's Oriole", 'White-tailed Hawk', 'Green Jay', 'Long-billed Thrasher', 'Black-bellied Whistling-Duck', "Morelet's Seedeater", 'Muscovy Duck', 'Verdin', 'Blue-headed Vireo', 'Cattle Egret', 'Black Vulture', 'Ash-throated Flycatcher', 'Cave Swallow', 'Summer Tanager', 'Cactus Wren', 'Ruby-throated Hummingbird', 'Pyrrhuloxia', 'Blue-winged Teal', 'Sharp-shinned Hawk', 'Sora', 'Northern Harrier']
#
# Top spot 2: ('26.9079878', '-99.2765808')
# Number possible targets: 79
# Most common targets: ['Chihuahuan Raven', 'Northern Cardinal', 'Great Kiskadee', 'Northern Mockingbird', 'Scissor-tailed Flycatcher', 'Golden-fronted Woodpecker', 'Altamira Oriole', 'Black-crested Titmouse', 'Great-tailed Grackle', 'Loggerhead Shrike', 'Lark Sparrow', 'Inca Dove', "Harris's Hawk", 'Laughing Gull', 'White-tipped Dove', "Audubon's Oriole", 'Plain Chachalaca', "Couch's Kingbird", 'Common Ground-Dove', 'Red-billed Pigeon', 'Cedar Waxwing', 'Spotted Sandpiper', 'Crested Caracara', 'Northern Rough-winged Swallow', 'Green Kingfisher', 'Purple Martin', 'Chimney Swift', 'Mottled Duck', 'Blue-gray Gnatcatcher', 'Brown-headed Cowbird', "Swainson's Hawk", 'Ringed Kingfisher', 'Barn Swallow', 'Cliff Swallow', 'Neotropic Cormorant', 'White-winged Dove', 'Curve-billed Thrasher', 'Common Yellowthroat', "Lincoln's Sparrow", 'Ladder-backed Woodpecker', 'Broad-winged Hawk', 'Lesser Nighthawk', 'Greater Roadrunner', 'Cinnamon Teal', 'Hooded Oriole', 'Black-chinned Hummingbird', 'Bank Swallow', 'Swamp Sparrow', 'Anhinga', 'Bronzed Cowbird', 'Red-shouldered Hawk', 'Caspian Tern', 'American Avocet', 'Green Heron', "Wilson's Snipe", 'Clay-colored Sparrow', 'Black-crowned Night-Heron', 'Olive Sparrow', "Bullock's Oriole", 'White-tailed Hawk', 'Green Jay', 'Long-billed Thrasher', 'Black-bellied Whistling-Duck', "Morelet's Seedeater", 'Muscovy Duck', 'Verdin', 'Blue-headed Vireo', 'Cattle Egret', 'Black Vulture', 'Ash-throated Flycatcher', 'Cave Swallow', 'Summer Tanager', 'Cactus Wren', 'Ruby-throated Hummingbird', 'Pyrrhuloxia', 'Blue-winged Teal', 'Sharp-shinned Hawk', 'Sora', 'Northern Harrier']
#
# Top spot 3: ('26.8812473', '-99.2507401')
# Number possible targets: 79
# Most common targets: ['Chihuahuan Raven', 'Northern Cardinal', 'Great Kiskadee', 'Northern Mockingbird', 'Scissor-tailed Flycatcher', 'Golden-fronted Woodpecker', 'Altamira Oriole', 'Black-crested Titmouse', 'Great-tailed Grackle', 'Loggerhead Shrike', 'Lark Sparrow', 'Inca Dove', "Harris's Hawk", 'Laughing Gull', 'White-tipped Dove', "Audubon's Oriole", 'Plain Chachalaca', "Couch's Kingbird", 'Common Ground-Dove', 'Red-billed Pigeon', 'Cedar Waxwing', 'Spotted Sandpiper', 'Crested Caracara', 'Northern Rough-winged Swallow', 'Green Kingfisher', 'Purple Martin', 'Chimney Swift', 'Mottled Duck', 'Blue-gray Gnatcatcher', 'Brown-headed Cowbird', "Swainson's Hawk", 'Ringed Kingfisher', 'Barn Swallow', 'Cliff Swallow', 'Neotropic Cormorant', 'White-winged Dove', 'Curve-billed Thrasher', 'Common Yellowthroat', "Lincoln's Sparrow", 'Ladder-backed Woodpecker', 'Broad-winged Hawk', 'Lesser Nighthawk', 'Greater Roadrunner', 'Cinnamon Teal', 'Hooded Oriole', 'Black-chinned Hummingbird', 'Bank Swallow', 'Swamp Sparrow', 'Anhinga', 'Bronzed Cowbird', 'Red-shouldered Hawk', 'Caspian Tern', 'American Avocet', 'Green Heron', "Wilson's Snipe", 'Clay-colored Sparrow', 'Black-crowned Night-Heron', 'Olive Sparrow', "Bullock's Oriole", 'White-tailed Hawk', 'Green Jay', 'Long-billed Thrasher', 'Black-bellied Whistling-Duck', "Morelet's Seedeater", 'Muscovy Duck', 'Verdin', 'Blue-headed Vireo', 'Cattle Egret', 'Black Vulture', 'Ash-throated Flycatcher', 'Cave Swallow', 'Summer Tanager', 'Cactus Wren', 'Ruby-throated Hummingbird', 'Pyrrhuloxia', 'Blue-winged Teal', 'Sharp-shinned Hawk', 'Sora', 'Northern Harrier']
#
# Top spot 4: ('26.5498192', '-99.1661596')
# Number possible targets: 79
# Most common targets: ['Chihuahuan Raven', 'Northern Cardinal', 'Great Kiskadee', 'Northern Mockingbird', 'Scissor-tailed Flycatcher', 'Golden-fronted Woodpecker', 'Altamira Oriole', 'Black-crested Titmouse', 'Great-tailed Grackle', 'Loggerhead Shrike', 'Lark Sparrow', 'Inca Dove', "Harris's Hawk", 'Laughing Gull', 'White-tipped Dove', "Audubon's Oriole", 'Plain Chachalaca', "Couch's Kingbird", 'Common Ground-Dove', 'Red-billed Pigeon', 'Cedar Waxwing', 'Spotted Sandpiper', 'Crested Caracara', 'Northern Rough-winged Swallow', 'Green Kingfisher', 'Purple Martin', 'Chimney Swift', 'Mottled Duck', 'Blue-gray Gnatcatcher', 'Brown-headed Cowbird', "Swainson's Hawk", 'Ringed Kingfisher', 'Barn Swallow', 'Cliff Swallow', 'Neotropic Cormorant', 'White-winged Dove', 'Curve-billed Thrasher', 'Common Yellowthroat', "Lincoln's Sparrow", 'Ladder-backed Woodpecker', 'Broad-winged Hawk', 'Lesser Nighthawk', 'Greater Roadrunner', 'Cinnamon Teal', 'Hooded Oriole', 'Black-chinned Hummingbird', 'Bank Swallow', 'Swamp Sparrow', 'Anhinga', 'Bronzed Cowbird', 'Red-shouldered Hawk', 'Caspian Tern', 'American Avocet', 'Green Heron', "Wilson's Snipe", 'Clay-colored Sparrow', 'Black-crowned Night-Heron', 'Olive Sparrow', "Bullock's Oriole", 'White-tailed Hawk', 'Green Jay', 'Long-billed Thrasher', 'Black-bellied Whistling-Duck', "Morelet's Seedeater", 'Muscovy Duck', 'Verdin', 'Blue-headed Vireo', 'Cattle Egret', 'Black Vulture', 'Ash-throated Flycatcher', 'Cave Swallow', 'Summer Tanager', 'Cactus Wren', 'Ruby-throated Hummingbird', 'Pyrrhuloxia', 'Blue-winged Teal', 'Sharp-shinned Hawk', 'Sora', 'Northern Harrier']
#
# Top spot 5: ('26.476905', '-99.0910149')
# Number possible targets: 79
# Most common targets: ['Chihuahuan Raven', 'Northern Cardinal', 'Great Kiskadee', 'Northern Mockingbird', 'Scissor-tailed Flycatcher', 'Golden-fronted Woodpecker', 'Altamira Oriole', 'Black-crested Titmouse', 'Great-tailed Grackle', 'Loggerhead Shrike', 'Lark Sparrow', 'Inca Dove', "Harris's Hawk", 'Laughing Gull', 'White-tipped Dove', "Audubon's Oriole", 'Plain Chachalaca', "Couch's Kingbird", 'Common Ground-Dove', 'Red-billed Pigeon', 'Cedar Waxwing', 'Spotted Sandpiper', 'Crested Caracara', 'Northern Rough-winged Swallow', 'Green Kingfisher', 'Purple Martin', 'Chimney Swift', 'Mottled Duck', 'Blue-gray Gnatcatcher', 'Brown-headed Cowbird', "Swainson's Hawk", 'Ringed Kingfisher', 'Barn Swallow', 'Cliff Swallow', 'Neotropic Cormorant', 'White-winged Dove', 'Curve-billed Thrasher', 'Common Yellowthroat', "Lincoln's Sparrow", 'Ladder-backed Woodpecker', 'Broad-winged Hawk', 'Lesser Nighthawk', 'Greater Roadrunner', 'Cinnamon Teal', 'Hooded Oriole', 'Black-chinned Hummingbird', 'Bank Swallow', 'Swamp Sparrow', 'Anhinga', 'Bronzed Cowbird', 'Red-shouldered Hawk', 'Caspian Tern', 'American Avocet', 'Green Heron', "Wilson's Snipe", 'Clay-colored Sparrow', 'Black-crowned Night-Heron', 'Olive Sparrow', "Bullock's Oriole", 'White-tailed Hawk', 'Green Jay', 'Long-billed Thrasher', 'Black-bellied Whistling-Duck', "Morelet's Seedeater", 'Muscovy Duck', 'Verdin', 'Blue-headed Vireo', 'Cattle Egret', 'Black Vulture', 'Ash-throated Flycatcher', 'Cave Swallow', 'Summer Tanager', 'Cactus Wren', 'Ruby-throated Hummingbird', 'Pyrrhuloxia', 'Blue-winged Teal', 'Sharp-shinned Hawk', 'Sora', 'Northern Harrier']
# {('46.6944318', '-60.3571701'): 6,
#  ('41.5851223', '-70.8219668'): 23,
#  ('41.9351042', '-82.5104141'): 21,
#  ('46.2722222', '-72.6111111'): 25,
#  ('46.65', '-71.566667'): 21,
#  ('21.9549272', '-159.335736'): 25,
#  ('38.0725405', '-122.8141122'): 32,
#  ('46.7561383', '-71.2436413'): 15,
#  ('43.3130395', '-77.7153471'): 18,
#  ('42.687714', '-70.6204365'): 45,
#  ('27.367185', '-82.626513'): 18,
#  ('43.8993331', '-77.2260182'): 20,
#  ('41.9435608', '-87.636194'): 39,
#  ('37.7542941', '-122.2506237'): 53,
#  ('21.2834562', '-157.7271429'): 7,
#  ('48.06667', '-65.56667'): 5,
#  ('29.4833333', '-94.5166667'): 28,
#  ('58.5175483', '-134.8334885'): 4,
#  ('44.8342', '-87.377'): 7,
#  ('41.2636142', '-72.561779'): 31,
#  ('46.8', '-71.18333'): 15,
#  ('21.4743695', '-157.9777679'): 7,
#  ('47.43333', '-70.01667'): 29,
#  ('22.1250826', '-159.6025085'): 25,
#  ('39.4727008', '-123.8042021'): 11,
#  ('43.1191394', '-70.8767004'): 46,
#  ('40.5108301', '-74.2097712'): 32,
#  ('48.1373395', '-122.565794'): 19,
#  ('21.9486586', '-159.3719729'): 25,
#  ('46.8489215', '-64.0144157'): 1,
#  ('49.1190163', '-123.1478441'): 23,
#  ('37.9331637', '-75.4159069'): 5,
#  ('47.1746616', '-88.2269096'): 1,
#  ('58.9415073', '-136.8010712'): 6,
#  ('48.5922568', '-123.0304022'): 24,
#  ('44.2262449', '-76.5386226'): 18,
#  ('30.246', '-87.70079'): 54,
#  ('49.1439869', '-125.9033203'): 17,
#  ('41.7520888', '-81.2927556'): 42,
#  ('48.93767', '-123.23718'): 23,
#  ('46.26667', '-72.61667'): 25,
#  ('30.2462407', '-88.0759066'): 58,
#  ('26.91', '-97.0566667'): 3,
#  ('41.832863', '-124.2165756'): 13,
#  ('48.85682', '-123.31239'): 23,
#  ('30.3466855', '-88.5519934'): 58,
#  ('19.5317501', '-155.9439926'): 11,
#  ('37.764744', '-122.5078583'): 42,
#  ('50.2', '-66.38333'): 7,
#  ('37.707319', '-122.1986961'): 51,
#  ('41.5679909', '-70.5149441'): 13,
#  ('41.3014861', '-72.1119044'): 32,
#  ('19.6482527', '-155.3710127'): 11,
#  ('30.2091599', '-88.9791107'): 63,
#  ('22.2039647', '-159.4907597'): 25,
#  ('44.4441366', '-68.3189964'): 9,
#  ('46.11667', '-73'): 24,
#  ('19.0849122', '-155.5504203'): 11,
#  ('30.5048923', '-81.4258575'): 21,
#  ('49.05', '-68.43333'): 21,
#  ('36.7984286', '-121.7900562'): 31,
#  ('39.4088845', '-123.810854'): 11,
#  ('49.5169621', '-124.5838182'): 10,
#  ('30.1516423', '-85.749431'): 3,
#  ('31.4332038', '-81.2391329'): 35,
#  ('45.46667', '-73.55'): 20,
#  ('45.2711657', '-66.0810084'): 6,
#  ('44.004715', '-76.085728'): 15,
#  ('53.3271823', '-131.9525814'): 1,
#  ('54.9523857', '-167.7062988'): 6,
#  ('22.150861', '-159.6221217'): 25,
#  ('33.7382322', '-118.107115'): 52,
#  ('41.2938255', '-124.0878189'): 13,
#  ('55.268652', '-162.899437'): 2,
#  ('48.5486601', '-58.6251068'): 2,
#  ('45.5231871', '-123.954277'): 1,
#  ('22.2072115', '-159.4754791'): 25,
#  ('38.3044865', '-75.1076889'): 7,
#  ('40.9609698', '-124.119021'): 13,
#  ('44.1250593', '-68.7089042'): 9,
#  ('39.2608978', '-84.738461'): 29,
#  ('39.8104223', '-82.7280539'): 18,
#  ('43.7313559', '-83.975206'): 6,
#  ('30.4112444', '-81.4206594'): 17,
#  ('43.5471294', '-79.5821225'): 27,
#  ('42.4928322', '-71.4726639'): 55,
#  ('44.0893', '-123.2945'): 19,
#  ('42.4203', '-87.8078'): 36,
#  ('45.2875233', '-74.6345932'): 16,
#  ('39.050897', '-77.0478477'): 42,
#  ('35.66591', '-75.4799'): 44,
#  ('61.1904127', '-149.8135185'): 1,
#  ('44.9309013', '-89.4582367'): 5,
#  ('40.044253', '-105.1867721'): 28,
#  ('42.417659', '-76.5186596'): 21,
#  ('43.1989441', '-71.5512353'): 47,
#  ('41.2793802', '-71.9807482'): 32,
#  ('47.55', '-68.91667'): 30,
#  ('46.4035986', '-119.7238111'): 9,
#  ('39.0438579', '-94.8070872'): 12,
#  ('40.7747109', '-73.9033963'): 32,
#  ('36.6422199', '-85.4968305'): 21,
#  ('39.2419444', '-83.366889'): 16,
#  ('36.10568', '-94.33271'): 40,
#  ('25.77428', '-80.19367'): 12,
#  ('38.5309118', '-121.7603159'): 37,
#  ('42.4144486', '-71.2386957'): 48,
#  ('41.7216426', '-111.7521135'): 1,
#  ('38.8555502', '-77.0488787'): 42,
#  ('42.2445312', '-76.7793274'): 21,
#  ('41.7661904', '-72.195282'): 43,
#  ('33.7981711', '-84.3170106'): 42,
#  ('34.3930006', '-119.5140259'): 17,
#  ('35.07788', '-87.43972'): 22,
#  ('36.06258', '-94.1574'): 40,
#  ('27.8275297', '-97.0789558'): 66,
#  ('41.2551091', '-72.0271611'): 32,
#  ('41.7960139', '-87.5765064'): 39,
#  ('41.578969', '-83.149142'): 28,
#  ('37.9751239', '-121.58638'): 54,
#  ('42.4246286', '-83.9977849'): 14,
#  ('26.476905', '-99.0910149'): 79,
#  ('42.3803902', '-72.5231323'): 31,
#  ('34.988877', '-90.1412445'): 65,
#  ('42.9736526', '-70.7647414'): 46,
#  ('34.2751625', '-119.2896366'): 23,
#  ('32.9927552', '-115.5427408'): 14,
#  ('50.3832391', '-114.6512604'): 9,
#  ('41.1021052', '-87.7611923'): 33,
#  ('38.89511', '-77.0364'): 42,
#  ('45.5986657', '-122.6117277'): 2,
#  ('42.9085938', '-70.9384632'): 48,
#  ('29.4704637', '-94.6026707'): 27,
#  ('37.8220227', '-120.1130533'): 9,
#  ('38.0148087', '-84.4844437'): 5,
#  ('42.6660066', '-71.372737'): 48,
#  ('40.35694', '-90.01344'): 18,
#  ('33.6965128', '-118.0451372'): 52,
#  ('34.260057', '-114.1580696'): 20,
#  ('29.4241295', '-98.4935913'): 40,
#  ('32.4424776', '-93.7241972'): 21,
#  ('43.6006167', '-88.17805'): 28,
#  ('27.0446212', '-99.4444013'): 79,
#  ('45.53333', '-75.41667'): 11,
#  ('48.3286239', '-68.8833761'): 28,
#  ('39.04538', '-82.13047'): 19,
#  ('51.5547464', '-107.9743023'): 5,
#  ('31.4892621', '-83.5359782'): 15,
#  ('38.2611314', '-121.4084959'): 32,
#  ('47.68333', '-68.88333'): 30,
#  ('42.3452195', '-76.2989625'): 21,
#  ('42.3531526', '-76.3015509'): 21,
#  ('42.4018864', '-71.1836621'): 48,
#  ('43.18061', '-87.90069'): 32,
#  ('39.0827724', '-77.4046549'): 42,
#  ('40.4742', '-95.73357'): 18,
#  ('38.9528278', '-85.818655'): 23,
#  ('42.253666', '-74.603371'): 6,
#  ('39.2287218', '-96.6335535'): 1,
#  ('38.758817', '-77.2624974'): 37,
#  ('44.3130401', '-78.327713'): 13,
#  ('32.4879724', '-93.745206'): 21,
#  ('44.1283752', '-71.4550781'): 5,
#  ('49.5190162', '-119.6210483'): 6,
#  ('42.9317791', '-88.033014'): 32,
#  ('42.2068681', '-86.355688'): 17,
#  ('44.1291227', '-121.3307548'): 9,
#  ('37.72858', '-89.16622'): 2,
#  ('40.561443', '-106.43767'): 4,
#  ('41.883981', '-94.1847856'): 4,
#  ('41.505492', '-71.0532188'): 25,
#  ('32.7620883', '-79.8309517'): 9,
#  ('31.7310142', '-110.881319'): 61,
#  ('32.3856344', '-112.8541522'): 4,
#  ('33.0364889', '-96.6640522'): 30,
#  ('44.3324439', '-120.8248901'): 9,
#  ('36.0568436', '-118.9279421'): 2,
#  ('36.9065', '-76.37'): 21,
#  ('27.5460543', '-81.4750715'): 29,
#  ('40.8709493', '-77.8601074'): 7,
#  ('46.880501', '-69.8586917'): 20,
#  ('41.4274277', '-72.0552278'): 32,
#  ('42.0297149', '-73.324728'): 26,
#  ('34.4580484', '-119.6923864'): 17,
#  ('42.5560835', '-118.9270234'): 1,
#  ('41.9283', '-87.637'): 39,
#  ('33.0959638', '-116.9994593'): 17,
#  ('46.1598231', '-72.7551065'): 25,
#  ('46.01667', '-73.45'): 24,
#  ('43.9584846', '-86.4461823'): 2,
#  ('44.9755611', '-92.904135'): 15,
#  ('32.42024', '-111.05794'): 56,
#  ('36.15399', '-95.99277'): 15,
#  ('55.219232', '-162.7236557'): 2,
#  ('36.6252236', '-121.9317888'): 27,
#  ('45.893324', '-77.282616'): 10,
#  ('50.2656', '-119.2713'): 10,
#  ('37.30444', '-122.0617801'): 45,
#  ('44.0696883', '-121.3122797'): 9,
#  ('39.7790361', '-86.1882248'): 23,
#  ('32.8832633', '-114.4662952'): 6,
#  ('31.4294687', '-100.4316044'): 1,
#  ('44.4510555', '-80.7624561'): 4,
#  ('44.6065063', '-87.4347076'): 8,
#  ('34.0623918', '-114.4316626'): 20,
#  ('40.9308721', '-73.4720876'): 27,
#  ('26.5498192', '-99.1661596'): 79,
#  ('43.10008', '-73.58176'): 14,
#  ('53.7244433', '-101.30476'): 3,
#  ('31.5427632', '-110.1337928'): 53,
#  ('43.716901', '-72.2774432'): 22,
#  ('41.5494034', '-70.6428679'): 13,
#  ('45.6117724', '-93.4141297'): 29,
#  ('37.5534237', '-121.5735054'): 50,
#  ('42.9550562', '-71.5233564'): 48,
#  ('44.5182665', '-72.3800514'): 12,
#  ('38.9933052', '-76.9388115'): 42,
#  ('42.4562676', '-72.6412582'): 31,
#  ('39.8798233', '-75.0686038'): 37,
#  ('43.8094931', '-79.9318836'): 26,
#  ('41.4993211', '-87.7601624'): 33,
#  ('25.9418086', '-81.4693308'): 35,
#  ('38.9826977', '-77.2316766'): 42,
#  ('32.960776', '-116.58008'): 22,
#  ('32.3946792', '-93.8269613'): 21,
#  ('29.95041', '-96.25579'): 19,
#  ('49.450568', '-124.7120561'): 22,
#  ('45.5202893', '-73.8485876'): 20,
#  ('41.2074598', '-95.8600044'): 18,
#  ('40.3242683', '-74.6630325'): 34,
#  ('30.2929326', '-89.8248088'): 25,
#  ('32.8423188', '-104.3971264'): 2,
#  ('43.6401056', '-79.4587255'): 28,
#  ('26.9079878', '-99.2765808'): 79,
#  ('31.3185944', '-81.5899658'): 31,
#  ('42.2020729', '-93.8138008'): 4,
#  ('30.4128402', '-88.4078837'): 58,
#  ('36.4087582', '-88.0588799'): 2,
#  ('41.1047811', '-74.4027856'): 32,
#  ('45.4520621', '-74.9414444'): 13,
#  ('40.585205', '-73.901276'): 30,
#  ('33.994871', '-119.63315'): 17,
#  ('47.9081', '-122.3062'): 17,
#  ('38.2289099', '-122.5980878'): 38,
#  ('44.0051', '-122.9631'): 19,
#  ('29.8937866', '-84.3737608'): 24,
#  ('33.4535184', '-111.7663622'): 25,
#  ('29.6450294', '-103.0795616'): 13,
#  ('43.6500587', '-79.3797989'): 28,
#  ('34.0616667', '-83.8675'): 42,
#  ('42.5462514', '-71.9091225'): 39,
#  ('44.4837266', '-71.1600137'): 4,
#  ('38.5421909', '-121.6247463'): 35,
#  ('43.1167735', '-78.4804916'): 32,
#  ('41.039341', '-75.6787872'): 13,
#  ('46.0625', '-93.05112'): 26,
#  ('26.7294962', '-81.8611339'): 39,
#  ('42.7577894', '-76.5581417'): 21,
#  ('47.5729936', '-52.72017'): 2,
#  ('37.7510367', '-121.9765663'): 54,
#  ('43.0243523', '-86.1907959'): 21,
#  ('46.367779', '-89.546814'): 2,
#  ('43.2129856', '-71.2320821'): 48,
#  ('48.28333', '-68.43333'): 28,
#  ('39.9910624', '-105.2205276'): 28,
#  ('39.5098683', '-84.0237808'): 33,
#  ('32.2570154', '-111.0307503'): 56,
#  ('33.7780824', '-117.7605691'): 52,
#  ('39.074423', '-77.341273'): 42,
#  ('47.3518432', '-61.8872094'): 5,
#  ('40.1899222', '-111.6458452'): 5,
#  ('46.909702', '-122.9083443'): 7,
#  ('40.7445511', '-81.9436413'): 8,
#  ('43.2581433', '-85.6878448'): 12,
#  ('29.4189184', '-103.1375027'): 13,
#  ('38.5622942', '-75.7206488'): 19,
#  ('41.5653', '-85.8322'): 16,
#  ('35.146301', '-79.159241'): 1,
#  ('39.461449', '-76.5628704'): 39,
#  ('47.53333', '-61.71667'): 5,
#  ('38.261064', '-75.9137034'): 5,
#  ('30.7214731', '-92.348671'): 17,
#  ('37.8132083', '-90.7724333'): 7,
#  ('40.9934692', '-72.5238113'): 31,
#  ('28.244633', '-96.8568259'): 66,
#  ('34.412', '-119.689'): 17,
#  ('41.78981', '-69.98976'): 11,
#  ('39.96009', '-75.20297'): 38,
#  ('42.675', '-80.5272'): 7,
#  ('37.6561013', '-98.9842844'): 4,
#  ('31.0289825', '-97.6065731'): 26,
#  ('46.83333', '-71.2'): 15,
#  ('48.3', '-64.71667'): 5,
#  ('30.4004752', '-91.6754794'): 17,
#  ('41.6413891', '-83.2405672'): 28,
#  ('44.0268059', '-77.7136561'): 21,
#  ('60.7189643', '-135.0562813'): 2,
#  ('41.7145615', '-87.839592'): 39,
#  ('42.25979', '-72.23982'): 35,
#  ('40.3911426', '-105.5110645'): 28,
#  ('43.4305', '-76.4647'): 14,
#  ('40.9955281', '-81.3606892'): 43,
#  ('39.3470425', '-74.7235107'): 26,
#  ('42.6602216', '-77.9486847'): 14,
#  ('33.0049926', '-97.1568203'): 30,
#  ('33.8372351', '-117.7554989'): 52,
#  ('37.4701657', '-122.3085463'): 48,
#  ('39.6091934', '-104.855149'): 26,
#  ('45.92659', '-116.12198'): 2,
#  ('49.21667', '-68.15'): 10,
#  ('45.61667', '-75.11667'): 11,
#  ('28.6439145', '-80.7165956'): 40,
#  ('42.6252', '-70.6907'): 45,
#  ('40.91051', '-73.1226536'): 29,
#  ('37.2863457', '-97.8133392'): 12,
#  ('34.9432656', '-115.5130219'): 3,
#  ('40.7558647', '-81.8452692'): 8,
#  ('39.361351', '-86.430933'): 23,
#  ('43.4240011', '-89.1698456'): 22,
#  ('43.2995889', '-73.19025'): 18,
#  ('40.8958677', '-72.3305511'): 30,
#  ('39.8875127', '-74.8907411'): 38,
#  ('34.98949', '-93.29738'): 2,
#  ('26.2232824', '-80.111661'): 12,
#  ('40.5923826', '-111.4441109'): 5,
#  ('28.5753263', '-80.9966826'): 40,
#  ('49.0965306', '-123.0823744'): 23,
#  ('34.267661', '-118.313214'): 54,
#  ('29.0528673', '-95.4263277'): 19,
#  ('36.4965275', '-82.6809812'): 4,
#  ('26.8812473', '-99.2507401'): 79,
#  ('43.225304', '-73.01956'): 17,
#  ('40.2043887', '-75.557847'): 28,
#  ('40.2048371', '-111.6487312'): 5,
#  ('39.0506788', '-77.0666691'): 42,
#  ('47.1734145', '-122.2051549'): 6,
#  ('33.996905', '-119.725714'): 17,
#  ('40.7933617', '-77.8600235'): 7,
#  ('50.5760422', '-113.8841057'): 9,
#  ('43.32', '-77.714'): 18,
#  ('38.550977', '-121.7314124'): 35,
#  ('32.0286983', '-80.8897483'): 33,
#  ('39.6036712', '-77.6243305'): 37,
#  ('43.0766232', '-89.4727957'): 8,
#  ('41.287401', '-72.3237662'): 31,
#  ('39.7331981', '-76.9583702'): 39,
#  ('34.2175513', '-118.1622505'): 53,
#  ('43.3021927', '-73.642271'): 16,
#  ('32.8834254', '-116.896677'): 17,
#  ('49.8105178', '-119.2037201'): 8,
#  ('35.2964933', '-119.1278243'): 3,
#  ('50.9285741', '-121.8160629'): 7,
#  ('42.06549', '-87.67695'): 36,
#  ('33.6045822', '-112.2548082'): 25,
#  ('40.5498905', '-73.9295769'): 30,
#  ('27.29312', '-81.36289'): 28,
#  ('44.8311201', '-73.2741446'): 19,
#  ('33.0908584', '-95.0073195'): 12,
#  ('40.0159146', '-105.3412485'): 28,
#  ('33.1983404', '-115.5798025'): 14,
#  ('42.35179', '-71.86342'): 39,
#  ('39.08401', '-76.70029'): 42,
#  ('30.4044428', '-87.8295565'): 54,
#  ('41.1708771', '-74.9145216'): 23,
#  ('49.1086017', '-125.7852173'): 17,
#  ('45.91715', '-89.24433'): 2,
#  ('38.9423332', '-92.3818016'): 10,
#  ('44.5874', '-79.9845'): 4,
#  ('33.0892404', '-95.0283051'): 12,
#  ('50.7663223', '-120.7521057'): 7,
#  ('34.0770681', '-106.8930041'): 2,
#  ('40.6666659', '-92.7613551'): 1,
#  ('45.40004', '-73.57959'): 20,
#  ('29.4656438', '-103.9759827'): 13,
#  ('33.77481', '-84.29632'): 42,
#  ('42.2142158', '-83.7285233'): 18,
#  ('34.277308', '-106.9000304'): 2,
#  ('43.8864629', '-78.6780583'): 31,
#  ('41.5879697', '-83.6143504'): 18,
#  ('42.5537363', '-71.8890917'): 39,
#  ('41.76182', '-72.72648'): 38,
#  ('25.4989223', '-80.4372559'): 12,
#  ('28.39359', '-81.5387'): 34,
#  ('41.6438307', '-71.5773118'): 34,
#  ('27.831562', '-97.0505834'): 66,
#  ('41.4500329', '-71.3990868'): 29,
#  ('46.65', '-71.93333'): 23,
#  ('30.2335', '-84.3052'): 24,
#  ('48.3446698', '-122.6696062'): 21,
#  ('32.3856386', '-99.7322125'): 3,
#  ('27.2952147', '-97.7302551'): 63,
#  ('47.7950237', '-120.7220221'): 3,
#  ('39.8139381', '-76.3288956'): 24,
#  ('36.7644743', '-76.251642'): 21,
#  ('42.1606041', '-122.6187515'): 2,
#  ('39.01325', '-114.12283'): 3,
#  ('44.29397', '-90.84834'): 2,
#  ('27.5964165', '-81.5045815'): 25,
#  ('46.13333', '-73.63333'): 24,
#  ('42.4709573', '-72.6397991'): 31,
#  ('37.6342177', '-97.3312283'): 12,
#  ('27.9059775', '-97.1912599'): 66,
#  ('38.5595761', '-121.3888192'): 23,
#  ('41.1690923', '-73.5496902'): 27,
#  ('42.6267913', '-70.946188'): 48,
#  ('33.58262', '-94.04269'): 1,
#  ('25.4686909', '-80.4775772'): 12,
#  ('43.7055925', '-79.2359948'): 29,
#  ('33.3009747', '-116.3875213'): 20,
#  ('41.167633', '-123.7399839'): 13,
#  ('39.5412714', '-82.9978108'): 27,
#  ('28.4705021', '-98.1806946'): 13,
#  ('41.5009477', '-95.9751444'): 14,
#  ('33.6263454', '-111.559056'): 25,
#  ('40.87406', '-98.3751'): 3,
#  ('44.44468', '-88.579'): 8,
#  ('45.6592575', '-73.4891903'): 24,
#  ('36.0097767', '-121.4523339'): 20,
#  ('44.7249633', '-65.5698433'): 7,
#  ('45.4192235', '-73.4936965'): 20,
#  ('44.0034225', '-77.1629906'): 22,
#  ('49.1373', '-123.0654'): 23,
#  ('44.4526536', '-63.724823'): 5,
#  ('48.05', '-65.48333'): 5,
#  ('44.49065', '-73.11097'): 10,
#  ('34.92484', '-81.0251'): 13,
#  ('45.6902932', '-111.0463715'): 1,
#  ('33.5603459', '-111.5363252'): 25,
#  ('33.9622825', '-98.6678874'): 3,
#  ('36.8734757', '-76.3064861'): 21,
#  ('43.9666667', '-78.1666667'): 23,
#  ('37.4752157', '-94.6981841'): 4,
#  ('37.4897534', '-84.4398052'): 7,
#  ('44.7427212', '-93.6159462'): 15,
#  ('48.2639374', '-68.7194824'): 28,
#  ('30.6275482', '-96.3349533'): 19,
#  ('48.417156', '-71.9452057'): 6,
#  ('50.2643967', '-119.316246'): 10,
#  ('32.90042', '-109.48318'): 6,
#  ('48.51667', '-68.46667'): 28,
#  ('35.6017763', '-83.7845596'): 5,
#  ('47.1459227', '-122.1429464'): 6,
#  ('27.874019', '-80.6143317'): 43,
#  ('32.3155238', '-110.8168709'): 56,
#  ('42.4568079', '-83.9950803'): 9,
#  ('50.669147', '-121.977895'): 7,
#  ('44.61409', '-68.3873'): 9,
#  ('36.0001688', '-88.1479615'): 2,
#  ('46.8926658', '-120.796566'): 2,
#  ('27.8247184', '-97.057305'): 66,
#  ('29.8828709', '-93.6241213'): 10,
#  ('42.6747056', '-113.490572'): 3,
#  ('41.5183463', '-84.2919159'): 17,
#  ('42.3508568', '-89.2367669'): 3,
#  ('42.3693489', '-70.9837818'): 48,
#  ('44.3356036', '-111.4671439'): 3,
#  ('41.5088344', '-101.3096523'): 3,
#  ('32.8210206', '-117.0849144'): 17,
#  ('35.2501716', '-91.5827289'): 5,
#  ('42.92699', '-70.9439'): 48,
#  ('27.3373671', '-81.9707537'): 34,
#  ('40.1004484', '-82.9013037'): 10,
#  ('40.1038352', '-76.4847994'): 21,
#  ('39.37219', '-104.85653'): 26,
#  ('35.716413', '-81.3565063'): 13,
#  ('32.8679137', '-116.4188629'): 22,
#  ('44.7423931', '-65.509926'): 7,
#  ('33.7396017', '-111.6597068'): 25,
#  ('44.8785819', '-122.929641'): 19,
#  ('41.2849121', '-81.3911896'): 43,
#  ('39.2109017', '-108.6820328'): 1,
#  ('47.688482', '-122.6753555'): 8,
#  ('39.3029227', '-74.534812'): 26,
#  ('35.055649', '-90.0705481'): 65,
#  ('41.8424969', '-88.0604626'): 39,
#  ('49.0392746', '-122.2202396'): 22,
#  ('35.1221551', '-90.0748444'): 65,
#  ('38.5464872', '-77.283926'): 37,
#  ('39.455803', '-82.9605747'): 27,
#  ('39.6372076', '-79.8132706'): 6,
#  ('43.1900025', '-71.7263192'): 31,
#  ('48.33333', '-70.88333'): 6,
#  ('40.1197294', '-102.3302436'): 4,
#  ('48.5197881', '-123.3896828'): 21,
#  ('37.9964', '-105.69957'): 4,
#  ('32.464639', '-94.7263527'): 26,
#  ('28.8967616', '-82.6588368'): 11,
#  ('31.3199143', '-89.2680359'): 9,
#  ('38.9424461', '-92.3912752'): 10,
#  ('35.35208', '-75.5104'): 44,
#  ('48.2966885', '-117.2498343'): 1,
#  ('38.640366', '-77.23429'): 37,
#  ('38.9558296', '-74.8730316'): 21,
#  ('49.4540594', '-123.1110978'): 21,
#  ('32.4473477', '-86.6579247'): 1,
#  ('44.298786', '-68.31674'): 9,
#  ('36.0928948', '-95.8932823'): 15,
#  ('35.072436', '-108.1077003'): 2,
#  ('46.7591453', '-92.0834835'): 1,
#  ('34.980628', '-91.205015'): 65,
#  ('30.40369', '-97.853928'): 26,
#  ('43.4653792', '-71.5391922'): 23,
#  ('35.0426463', '-97.8761673'): 1,
#  ('40.7845001', '-73.8439026'): 30,
#  ('40.6680222', '-73.96367'): 32,
#  ('48.46667', '-71.65'): 6,
#  ('43.2626633', '-79.9422151'): 28,
#  ('39.2462567', '-75.1306433'): 28,
#  ('47.55', '-68.65'): 28,
#  ('30.4162677', '-88.9086082'): 63,
#  ('50.7835822', '-119.3139267'): 8,
#  ('41.452559', '-81.8250294'): 46,
#  ('41.1771052', '-100.9900665'): 3,
#  ('37.8691452', '-87.803185'): 4,
#  ('30.1157307', '-84.9878311'): 24,
#  ('43.0731049', '-81.3755393'): 6,
#  ('44.1887912', '-73.4342089'): 10,
#  ('32.589696', '-117.1323348'): 17,
#  ('46.66667', '-71.58333'): 21,
#  ('39.7597275', '-79.5439339'): 6,
#  ('58.5225682', '-134.8283815'): 4,
#  ('35.8641653', '-81.3683242'): 4,
#  ('30.784244', '-88.102541'): 54,
#  ('41.9225', '-88.0542'): 39,
#  ('43.3869019', '-80.3802501'): 27,
#  ('45.3', '-74.03333'): 18,
#  ('28.2232039', '-98.5669327'): 13,
#  ('29.93292', '-83.075695'): 11,
#  ('36.1211676', '-97.1009445'): 3,
#  ('37.2517139', '-85.3305954'): 22,
#  ('38.6949727', '-119.9893391'): 9,
#  ('32.77544', '-79.8132706'): 9,
#  ('40.2714588', '-75.4576743'): 28,
#  ('47.436688', '-122.2917143'): 7,
#  ('33.97664', '-83.89312'): 42,
#  ('37.8948386', '-122.5017214'): 44,
#  ('43.362727', '-73.0522328'): 20,
#  ('44.91971', '-89.62107'): 5,
#  ('44.2962776', '-117.2225218'): 2,
#  ('38.9778882', '-77.0074765'): 42,
#  ('43.5619838', '-72.4354362'): 21,
#  ('43.0006299', '-70.756588'): 46,
#  ('28.7190353', '-81.4740985'): 31,
#  ('44.0875234', '-73.3452845'): 20,
#  ('30.5215667', '-84.2697716'): 24,
#  ('46.75', '-71.26667'): 15,
#  ('39.317463', '-81.66503'): 16,
#  ('40.891326', '-73.2149291'): 26,
#  ('50.4024193', '-107.4023473'): 2,
#  ('34.7720005', '-118.4588857'): 13,
#  ('39.3445678', '-104.6951348'): 26,
#  ('44.6796291', '-76.3948059'): 13,
#  ('32.309261', '-95.3772047'): 12,
#  ('29.4782878', '-94.5799145'): 27,
#  ('39.2720509', '-76.7319161'): 44,
#  ('37.4730423', '-122.1907327'): 51,
#  ('42.3513889', '-72.4125'): 33,
#  ('38.4136093', '-75.5105352'): 19,
#  ('29.5412036', '-95.0118256'): 27,
#  ('36.4331608', '-111.8507767'): 1,
#  ('38.0916848', '-87.2877592'): 4,
#  ('34.923922', '-112.473551'): 1,
#  ('43.9561111', '-78.1530556'): 23,
#  ('38.6177869', '-79.9315367'): 1,
#  ('50.41487', '-119.25074'): 9,
#  ('48.35', '-69.4'): 28,
#  ('46.7244487', '-123.8542682'): 2,
#  ('40.447706', '-75.58247'): 29,
#  ('34.278988', '-80.59087'): 11,
#  ('48.5375793', '-121.7443514'): 14,
#  ('45.29463', '-64.7723'): 3,
#  ('49.3625513', '-126.2782288'): 17,
#  ('29.531696', '-82.8228164'): 21,
#  ('39.7705145', '-122.2039318'): 1,
#  ('40.1219633', '-102.6957684'): 4,
#  ('34.78479', '-91.45843'): 5,
#  ('49.1778', '-123.1474'): 22,
#  ('39.8986359', '-75.4029007'): 39,
#  ('46.9413778', '-120.2034142'): 10,
#  ('43.1011629', '-90.8591679'): 1,
#  ('41.9547519', '-75.2963715'): 21,
#  ('40.4860564', '-89.020858'): 18,
#  ('50.188333', '-97.136667'): 1,
#  ('41.5428589', '-70.6228209'): 13}

# %% [markdown]
# # Global big day

# %%
engine_path = "/Volumes/seagate-storage/db/ebird_small.db"
table_name = 'ebird_small_20190328'
lifelist_filename = 'blank-lifelist.csv'
month = 5
day = 4
padding = 10
num_spots = 5
radius_miles = 5

big_day = chaser(
    engine_path,
    table_name,
    lifelist_filename,
    month,
    day,
    padding,
    num_spots,
    radius_miles
)

big_day
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
# Top spot 1: ('41.7525432', '-81.2912294')
# Number possible targets: 206
# Most common targets: ['Northern Cardinal', 'Common Grackle', 'Song Sparrow', 'Yellow Warbler', 'Gray Catbird', 'House Wren', 'Northern Flicker', 'Red-winged Blackbird', 'American Goldfinch', 'American Robin', 'American Crow', 'Ring-billed Gull', 'Barn Swallow', 'Blue Jay', 'Baltimore Oriole', 'European Starling', 'Brown Thrasher', 'Killdeer', 'Brown-headed Cowbird', 'Common Yellowthroat', 'House Sparrow', 'Eastern Towhee', 'Yellow-rumped Warbler', 'Wood Thrush', 'Downy Woodpecker', 'Mourning Dove', 'Black-capped Chickadee', 'Chimney Swift', 'Warbling Vireo', 'White-crowned Sparrow', 'Tree Swallow', 'Spotted Sandpiper', 'Tufted Titmouse', 'White-throated Sparrow', 'Herring Gull', 'Red-headed Woodpecker', 'Great Blue Heron', 'Palm Warbler', 'Ruby-crowned Kinglet', 'Chipping Sparrow', 'Northern Rough-winged Swallow', 'Mallard', 'American Redstart', 'Purple Martin', 'Canada Goose', 'Black-and-white Warbler', 'Eastern Kingbird', 'Rose-breasted Grosbeak', 'White-breasted Nuthatch', 'Wood Duck', 'Blue-gray Gnatcatcher', 'Ovenbird', 'Least Flycatcher', 'Belted Kingfisher', 'Veery', 'Magnolia Warbler', 'Red-bellied Woodpecker', 'Black-throated Blue Warbler', 'Chestnut-sided Warbler', 'Nashville Warbler', 'Field Sparrow', 'Red-eyed Vireo', 'Green Heron', 'House Finch', 'Scarlet Tanager', "Bonaparte's Gull", 'Indigo Bunting', 'Caspian Tern', 'Bank Swallow', 'Eastern Phoebe', 'Eastern Wood-Pewee', "Lincoln's Sparrow", 'Great Crested Flycatcher', "Swainson's Thrush", 'Swamp Sparrow', 'Double-crested Cormorant', 'Turkey Vulture', 'Red-breasted Merganser', 'Blue-winged Warbler', 'Blackburnian Warbler', 'Black-throated Green Warbler', 'Hermit Thrush', "Wilson's Warbler", 'Red-breasted Nuthatch', 'American Coot', 'Tennessee Warbler', 'Solitary Sandpiper', 'Cedar Waxwing', 'Northern Waterthrush', 'Sharp-shinned Hawk', 'American Kestrel', 'Carolina Wren', 'Ruby-throated Hummingbird', 'Eastern Bluebird', 'Prothonotary Warbler', 'Common Tern', 'Eastern Meadowlark', 'Great Black-backed Gull', 'Blue-headed Vireo', 'Blue-winged Teal', 'White-eyed Vireo', 'Great Egret', 'Bay-breasted Warbler', 'Canada Warbler', "Forster's Tern", 'Cape May Warbler', 'Yellow-bellied Sapsucker', 'Orchard Oriole', 'Common Gallinule', 'Purple Finch', 'Hairy Woodpecker', 'American Black Duck', "Cooper's Hawk", 'Marsh Wren', 'Black-crowned Night-Heron', 'Pileated Woodpecker', 'Bobolink', 'Savannah Sparrow', 'Yellow-breasted Chat', 'Ruddy Turnstone', 'Northern Mockingbird', 'American Pipit', 'Winter Wren', 'Lesser Scaup', 'Greater Yellowlegs', 'Common Loon', 'Pied-billed Grebe', 'Hooded Warbler', 'Barred Owl', 'Northern Harrier', 'Ruddy Duck', 'Least Sandpiper', 'Dark-eyed Junco', 'Gray-cheeked Thrush', 'Northern Bobwhite', 'Orange-crowned Warbler', 'Red-tailed Hawk', 'Sora', 'Lesser Yellowlegs', 'Northern Parula', 'Black-billed Cuckoo', 'Brown Creeper', 'Rusty Blackbird', 'Evening Grosbeak', 'Great Horned Owl', 'Golden-crowned Kinglet', 'Cliff Swallow', 'Blackpoll Warbler', 'Louisiana Waterthrush', 'Sanderling', 'Philadelphia Vireo', 'Common Nighthawk', 'Pine Siskin', 'Dunlin', 'American Bittern', 'Yellow-throated Vireo', 'Common Merganser', 'Grasshopper Sparrow', 'Willow Flycatcher', 'Golden-winged Warbler', 'Black-bellied Plover', 'Osprey', 'Cerulean Warbler', 'Ring-necked Pheasant', 'American Woodcock', 'Red-shouldered Hawk', 'Merlin', 'Black Tern', 'Mute Swan', 'Mourning Warbler', 'Bufflehead', 'Kentucky Warbler', 'American Tree Sparrow', 'Northern Shoveler', 'Broad-winged Hawk', 'Acadian Flycatcher', 'Ring-necked Duck', 'Bald Eagle', 'Short-billed Dowitcher', 'Hooded Merganser', "Wilson's Snipe", 'Vesper Sparrow', 'Purple Gallinule', 'Snowy Egret', 'Northern Goshawk', 'Olive-sided Flycatcher', 'Red-throated Loon', 'Connecticut Warbler', 'Peregrine Falcon', 'Horned Lark', "Nelson's Sparrow", 'Sedge Wren', 'Summer Tanager', 'Least Bittern', 'Yellow-bellied Flycatcher', 'Snow Goose', 'Eastern Whip-poor-will', 'Clay-colored Sparrow', 'Pectoral Sandpiper', 'Red Knot', 'Sandh ...
#
# Top spot 2: ('41.7520888', '-81.2927556')
# Number possible targets: 206
# Most common targets: ['Northern Cardinal', 'Common Grackle', 'Song Sparrow', 'Yellow Warbler', 'Gray Catbird', 'House Wren', 'Northern Flicker', 'Red-winged Blackbird', 'American Goldfinch', 'American Robin', 'American Crow', 'Ring-billed Gull', 'Barn Swallow', 'Blue Jay', 'Baltimore Oriole', 'European Starling', 'Brown Thrasher', 'Killdeer', 'Brown-headed Cowbird', 'Common Yellowthroat', 'House Sparrow', 'Eastern Towhee', 'Yellow-rumped Warbler', 'Wood Thrush', 'Downy Woodpecker', 'Mourning Dove', 'Black-capped Chickadee', 'Chimney Swift', 'Warbling Vireo', 'White-crowned Sparrow', 'Tree Swallow', 'Spotted Sandpiper', 'Tufted Titmouse', 'White-throated Sparrow', 'Herring Gull', 'Red-headed Woodpecker', 'Great Blue Heron', 'Palm Warbler', 'Ruby-crowned Kinglet', 'Chipping Sparrow', 'Northern Rough-winged Swallow', 'Mallard', 'American Redstart', 'Purple Martin', 'Canada Goose', 'Black-and-white Warbler', 'Eastern Kingbird', 'Rose-breasted Grosbeak', 'White-breasted Nuthatch', 'Wood Duck', 'Blue-gray Gnatcatcher', 'Ovenbird', 'Least Flycatcher', 'Belted Kingfisher', 'Veery', 'Magnolia Warbler', 'Red-bellied Woodpecker', 'Black-throated Blue Warbler', 'Chestnut-sided Warbler', 'Nashville Warbler', 'Field Sparrow', 'Red-eyed Vireo', 'Green Heron', 'House Finch', 'Scarlet Tanager', "Bonaparte's Gull", 'Indigo Bunting', 'Caspian Tern', 'Bank Swallow', 'Eastern Phoebe', 'Eastern Wood-Pewee', "Lincoln's Sparrow", 'Great Crested Flycatcher', "Swainson's Thrush", 'Swamp Sparrow', 'Double-crested Cormorant', 'Turkey Vulture', 'Red-breasted Merganser', 'Blue-winged Warbler', 'Blackburnian Warbler', 'Black-throated Green Warbler', 'Hermit Thrush', "Wilson's Warbler", 'Red-breasted Nuthatch', 'American Coot', 'Tennessee Warbler', 'Solitary Sandpiper', 'Cedar Waxwing', 'Northern Waterthrush', 'Sharp-shinned Hawk', 'American Kestrel', 'Carolina Wren', 'Ruby-throated Hummingbird', 'Eastern Bluebird', 'Prothonotary Warbler', 'Common Tern', 'Eastern Meadowlark', 'Great Black-backed Gull', 'Blue-headed Vireo', 'Blue-winged Teal', 'White-eyed Vireo', 'Great Egret', 'Bay-breasted Warbler', 'Canada Warbler', "Forster's Tern", 'Cape May Warbler', 'Yellow-bellied Sapsucker', 'Orchard Oriole', 'Common Gallinule', 'Purple Finch', 'Hairy Woodpecker', 'American Black Duck', "Cooper's Hawk", 'Marsh Wren', 'Black-crowned Night-Heron', 'Pileated Woodpecker', 'Bobolink', 'Savannah Sparrow', 'Yellow-breasted Chat', 'Ruddy Turnstone', 'Northern Mockingbird', 'American Pipit', 'Winter Wren', 'Lesser Scaup', 'Greater Yellowlegs', 'Common Loon', 'Pied-billed Grebe', 'Hooded Warbler', 'Barred Owl', 'Northern Harrier', 'Ruddy Duck', 'Least Sandpiper', 'Dark-eyed Junco', 'Gray-cheeked Thrush', 'Northern Bobwhite', 'Orange-crowned Warbler', 'Red-tailed Hawk', 'Sora', 'Lesser Yellowlegs', 'Northern Parula', 'Black-billed Cuckoo', 'Brown Creeper', 'Rusty Blackbird', 'Evening Grosbeak', 'Great Horned Owl', 'Golden-crowned Kinglet', 'Cliff Swallow', 'Blackpoll Warbler', 'Louisiana Waterthrush', 'Sanderling', 'Philadelphia Vireo', 'Common Nighthawk', 'Pine Siskin', 'Dunlin', 'American Bittern', 'Yellow-throated Vireo', 'Common Merganser', 'Grasshopper Sparrow', 'Willow Flycatcher', 'Golden-winged Warbler', 'Black-bellied Plover', 'Osprey', 'Cerulean Warbler', 'Ring-necked Pheasant', 'American Woodcock', 'Red-shouldered Hawk', 'Merlin', 'Black Tern', 'Mute Swan', 'Mourning Warbler', 'Bufflehead', 'Kentucky Warbler', 'American Tree Sparrow', 'Northern Shoveler', 'Broad-winged Hawk', 'Acadian Flycatcher', 'Ring-necked Duck', 'Bald Eagle', 'Short-billed Dowitcher', 'Hooded Merganser', "Wilson's Snipe", 'Vesper Sparrow', 'Purple Gallinule', 'Snowy Egret', 'Northern Goshawk', 'Olive-sided Flycatcher', 'Red-throated Loon', 'Connecticut Warbler', 'Peregrine Falcon', 'Horned Lark', "Nelson's Sparrow", 'Sedge Wren', 'Summer Tanager', 'Least Bittern', 'Yellow-bellied Flycatcher', 'Snow Goose', 'Eastern Whip-poor-will', 'Clay-colored Sparrow', 'Pectoral Sandpiper', 'Red Knot', 'Sandh ...
#
# Top spot 3: ('39.2608978', '-84.738461')
# Number possible targets: 149
# Most common targets: ['Cerulean Warbler', 'Warbling Vireo', 'Northern Rough-winged Swallow', 'Yellow Warbler', 'Indigo Bunting', 'American Goldfinch', "Swainson's Thrush", 'Tennessee Warbler', 'Northern Flicker', 'Gray Catbird', 'House Sparrow', 'Eastern Towhee', 'Blue Jay', 'Blue-winged Teal', 'Blue-gray Gnatcatcher', 'Song Sparrow', 'Rose-breasted Grosbeak', 'Wood Thrush', 'Northern Cardinal', 'Baltimore Oriole', 'European Starling', 'Ovenbird', 'Chimney Swift', 'Common Yellowthroat', 'Hooded Warbler', 'Great Crested Flycatcher', 'Scarlet Tanager', 'Solitary Sandpiper', 'White-eyed Vireo', 'Tree Swallow', 'Red-winged Blackbird', 'Eastern Wood-Pewee', 'American Robin', 'Lesser Yellowlegs', 'Carolina Wren', 'Downy Woodpecker', 'Turkey Vulture', 'White-crowned Sparrow', 'Red-tailed Hawk', 'Pileated Woodpecker', 'Orchard Oriole', 'Great Blue Heron', 'Veery', 'Sora', 'Northern Bobwhite', 'Palm Warbler', 'Eastern Bluebird', 'Mourning Dove', 'Carolina Chickadee', 'House Wren', 'Kentucky Warbler', 'Tufted Titmouse', 'Yellow-throated Vireo', 'Barn Swallow', 'Wood Duck', 'Summer Tanager', 'Blackburnian Warbler', 'Nashville Warbler', 'White-throated Sparrow', 'Yellow-rumped Warbler', 'Northern Mockingbird', 'Canada Goose', 'Chestnut-sided Warbler', 'White-breasted Nuthatch', 'Black-and-white Warbler', 'Eastern Meadowlark', 'Pied-billed Grebe', 'Brown-headed Cowbird', 'Chipping Sparrow', 'Yellow-throated Warbler', 'Acadian Flycatcher', 'American Crow', 'Blackpoll Warbler', 'Field Sparrow', 'Bank Swallow', 'Brown Thrasher', 'Belted Kingfisher', 'Eastern Phoebe', 'Cedar Waxwing', 'Red-bellied Woodpecker', 'Common Grackle', 'Blue-winged Warbler', 'Greater Yellowlegs', 'Louisiana Waterthrush', 'Ruby-throated Hummingbird', 'Killdeer', 'Black-throated Green Warbler', 'Savannah Sparrow', 'Gadwall', 'Northern Parula', 'American Bittern', 'Green Heron', 'American Kestrel', 'Ruddy Duck', 'Yellow-billed Cuckoo', 'House Finch', 'Sedge Wren', 'Magnolia Warbler', 'Hairy Woodpecker', 'Swamp Sparrow', 'Black-throated Blue Warbler', 'Willow Flycatcher', 'Least Flycatcher', 'Yellow-breasted Chat', 'Pectoral Sandpiper', 'Gray-cheeked Thrush', 'Virginia Rail', "Wilson's Snipe", 'Least Sandpiper', 'Worm-eating Warbler', 'Spotted Sandpiper', 'Mallard', 'Red-shouldered Hawk', 'Wild Turkey', 'Semipalmated Plover', 'Purple Martin', 'Cape May Warbler', 'Hooded Merganser', 'Semipalmated Sandpiper', 'Horned Lark', 'Mourning Warbler', 'Bay-breasted Warbler', 'Double-crested Cormorant', 'Great Horned Owl', 'Marsh Wren', 'Red-eyed Vireo', 'Purple Finch', 'Short-billed Dowitcher', 'Least Bittern', 'Prairie Warbler', "Wilson's Warbler", "Bell's Vireo", 'Red-breasted Merganser', 'Northern Waterthrush', 'Bobolink', 'Ring-necked Duck', 'Broad-winged Hawk', 'Prothonotary Warbler', 'Blue-headed Vireo', 'Barred Owl', 'Eastern Kingbird', "Cooper's Hawk", 'Cliff Swallow', "Henslow's Sparrow", 'Grasshopper Sparrow', 'Red-breasted Nuthatch', 'Ruby-crowned Kinglet', 'American Coot', 'Northern Shoveler']
#
# Top spot 4: ('41.9351042', '-82.5104141')
# Number possible targets: 145
# Most common targets: ['Yellow Warbler', 'Northern Flicker', 'Barn Swallow', 'Black-throated Green Warbler', 'Rose-breasted Grosbeak', 'White-crowned Sparrow', 'Least Flycatcher', 'Blue-headed Vireo', 'Eastern Kingbird', 'Gray Catbird', 'Baltimore Oriole', 'Ruby-crowned Kinglet', 'Blue Jay', 'Black-and-white Warbler', 'Nashville Warbler', 'Blue-gray Gnatcatcher', 'Field Sparrow', 'Black-throated Blue Warbler', 'Indigo Bunting', 'American Robin', 'Orchard Oriole', 'Palm Warbler', 'Chipping Sparrow', 'American Goldfinch', 'Veery', 'House Wren', 'Magnolia Warbler', 'Yellow-rumped Warbler', 'Warbling Vireo', 'Cape May Warbler', 'Cedar Waxwing', 'Scarlet Tanager', "Lincoln's Sparrow", 'Chimney Swift', 'Northern Cardinal', 'Red-eyed Vireo', 'Common Yellowthroat', "Swainson's Thrush", 'Mourning Dove', 'Red-breasted Merganser', 'American Redstart', 'Blackburnian Warbler', 'Red-headed Woodpecker', 'Alder Flycatcher', 'Great Blue Heron', 'American Crow', 'Grasshopper Sparrow', "Bonaparte's Gull", 'Ring-billed Gull', 'Brown-headed Cowbird', 'Orange-crowned Warbler', 'Black-crowned Night-Heron', 'Common Tern', 'White-throated Sparrow', "Wilson's Warbler", 'Cerulean Warbler', 'Tree Swallow', 'Brown Thrasher', 'Ruby-throated Hummingbird', 'Savannah Sparrow', 'Red-breasted Nuthatch', 'Herring Gull', 'Common Grackle', 'Red-winged Blackbird', 'Eastern Towhee', 'Eastern Meadowlark', 'Double-crested Cormorant', 'Lesser Scaup', 'Canada Goose', 'Red-tailed Hawk', 'Great Egret', 'Turkey Vulture', 'Chestnut-sided Warbler', 'Northern Parula', 'Blue-winged Teal', 'Carolina Wren', 'Ruddy Turnstone', 'Swamp Sparrow', 'Canada Warbler', 'Hermit Thrush', 'White-eyed Vireo', 'Killdeer', 'Ovenbird', 'Northern Shoveler', 'Black-bellied Plover', 'Gadwall', 'Northern Harrier', 'Mallard', 'Downy Woodpecker', 'House Sparrow', 'American Coot', 'Greater Yellowlegs', "Forster's Tern", 'House Finch', 'Red-bellied Woodpecker', 'Tennessee Warbler', 'European Starling', 'Acadian Flycatcher', 'Caspian Tern', 'Hooded Warbler', 'American Wigeon', 'Eastern Screech-Owl', 'Bank Swallow', 'Song Sparrow', 'Surf Scoter', 'Solitary Sandpiper', 'White-breasted Nuthatch', 'Yellow-breasted Chat', 'Black-capped Chickadee', 'Blue-winged Warbler', 'Golden-crowned Kinglet', 'Mourning Warbler', 'Broad-winged Hawk', 'Greater Scaup', 'Brown Creeper', 'Blue Grosbeak', 'Horned Lark', 'Eastern Wood-Pewee', 'Marsh Wren', 'Wood Thrush', 'Bufflehead', 'Black Tern', 'Ruddy Duck', 'Bobolink', "Henslow's Sparrow", 'Bald Eagle', 'Philadelphia Vireo', 'Ring-necked Pheasant', 'Bay-breasted Warbler', 'Blackpoll Warbler', 'Northern Waterthrush', 'Purple Finch', 'Green Heron', 'Great Crested Flycatcher', 'Wild Turkey', 'Purple Martin', 'Ring-necked Duck', 'American Kestrel', 'American Black Duck', 'Sanderling', 'Pine Warbler', 'Spotted Sandpiper', 'Lesser Yellowlegs', 'Belted Kingfisher', 'Great Black-backed Gull']
#
# Top spot 5: ('41.914899', '-82.509789')
# Number possible targets: 142
# Most common targets: ['Yellow Warbler', 'Northern Flicker', 'Rose-breasted Grosbeak', 'White-crowned Sparrow', 'Barn Swallow', 'Black-throated Green Warbler', 'Least Flycatcher', 'Field Sparrow', 'Baltimore Oriole', 'Eastern Kingbird', 'Blue-headed Vireo', 'Gray Catbird', 'Indigo Bunting', 'Black-throated Blue Warbler', 'Ruby-crowned Kinglet', 'American Robin', 'Magnolia Warbler', 'Black-and-white Warbler', 'Palm Warbler', 'Blue-gray Gnatcatcher', 'Blue Jay', 'Cedar Waxwing', 'Nashville Warbler', 'American Goldfinch', 'Warbling Vireo', 'Red-eyed Vireo', 'Veery', 'Orchard Oriole', "Lincoln's Sparrow", 'Chipping Sparrow', 'Yellow-rumped Warbler', 'House Wren', 'Cape May Warbler', 'Northern Cardinal', 'Red-headed Woodpecker', 'Chimney Swift', 'Common Yellowthroat', 'Scarlet Tanager', 'Alder Flycatcher', "Swainson's Thrush", 'Mourning Dove', 'Brown Thrasher', "Wilson's Warbler", 'American Redstart', 'Red-breasted Merganser', 'Orange-crowned Warbler', 'Black-crowned Night-Heron', 'Herring Gull', 'Savannah Sparrow', 'Great Blue Heron', "Bonaparte's Gull", 'Grasshopper Sparrow', 'Blackburnian Warbler', 'Ring-billed Gull', 'Common Tern', 'Hermit Thrush', 'White-throated Sparrow', 'Eastern Towhee', 'Cerulean Warbler', 'Eastern Meadowlark', 'Common Grackle', 'Red-breasted Nuthatch', 'Swamp Sparrow', 'American Crow', 'Canada Warbler', 'Ruddy Turnstone', 'Ruby-throated Hummingbird', 'Brown-headed Cowbird', 'Tree Swallow', 'American Wigeon', 'Hooded Warbler', 'Acadian Flycatcher', 'White-breasted Nuthatch', 'Lesser Scaup', 'White-eyed Vireo', 'Caspian Tern', 'Black-bellied Plover', 'American Coot', 'Canada Goose', 'Bank Swallow', 'Mallard', 'Double-crested Cormorant', 'Ovenbird', 'Red-winged Blackbird', 'Red-bellied Woodpecker', 'Great Egret', 'Red-tailed Hawk', 'Yellow-breasted Chat', 'Eastern Screech-Owl', 'Killdeer', 'Gadwall', 'Blue-winged Teal', 'Northern Harrier', 'Northern Parula', 'Downy Woodpecker', 'Carolina Wren', 'Tennessee Warbler', 'Northern Shoveler', 'Turkey Vulture', 'House Finch', 'Chestnut-sided Warbler', 'Greater Yellowlegs', 'House Sparrow', 'Spotted Sandpiper', 'Mourning Warbler', 'Brown Creeper', 'Song Sparrow', "Forster's Tern", 'Broad-winged Hawk', 'Solitary Sandpiper', 'Eastern Wood-Pewee', 'European Starling', 'Golden-crowned Kinglet', 'Belted Kingfisher', 'Blue Grosbeak', 'Black Tern', 'Surf Scoter', 'Bobolink', 'Pine Warbler', 'Green Heron', 'Ring-necked Duck', 'Blackpoll Warbler', 'Bay-breasted Warbler', 'American Kestrel', 'Ring-necked Pheasant', 'Philadelphia Vireo', 'American Black Duck', 'Sanderling', 'Great Black-backed Gull', 'Marsh Wren', 'Purple Finch', 'Bufflehead', 'Lesser Yellowlegs', "Henslow's Sparrow", 'Horned Lark', 'Bald Eagle', 'Greater Scaup', 'Wood Thrush', 'Blue-winged Warbler', 'Black-capped Chickadee', 'Great Crested Flycatcher', 'Ruddy Duck']
# {('44.5933032', '-124.39888'): 11,
#  ('46.8341927', '-71.0290924'): 5,
#  ('47.6634667', '-122.4218833'): 38,
#  ('41.9351042', '-82.5104141'): 145,
#  ('40.6233341', '-73.5014534'): 12,
#  ('36.9182984', '-76.0542297'): 37,
#  ('46.2566183', '-72.6331902'): 40,
#  ('65.2365', '-126.6939'): 21,
#  ('43.8993331', '-77.2260182'): 22,
#  ('21.9549272', '-159.335736'): 2,
#  ('21.8805358', '-159.4744492'): 1,
#  ('43.3130395', '-77.7153471'): 115,
#  ('42.0839551', '-70.0490427'): 1,
#  ('44.8342', '-87.377'): 21,
#  ('37.3578012', '-122.4006665'): 1,
#  ('47.9404107', '-69.5062923'): 70,
#  ('41.0352234', '-124.1231918'): 3,
#  ('41.9435608', '-87.636194'): 74,
#  ('46.8', '-71.18333'): 29,
#  ('46.2722222', '-72.6111111'): 40,
#  ('43.219329', '-79.2162108'): 58,
#  ('44.6156447', '-124.0665436'): 6,
#  ('29.4833333', '-94.5166667'): 17,
#  ('38.005', '-74.474444'): 4,
#  ('39.4727008', '-123.8042021'): 36,
#  ('41.7525432', '-81.2912294'): 206,
#  ('49.3071194', '-123.0042861'): 14,
#  ('37.7869181', '-122.499596'): 3,
#  ('49.2957439', '-123.1528437'): 26,
#  ('46.6944318', '-60.3571701'): 12,
#  ('24.882193', '-80.6902456'): 4,
#  ('50.8059347', '-127.3699951'): 17,
#  ('25.9950812', '-97.3196411'): 4,
#  ('22.120003', '-159.5626317'): 6,
#  ('41.3195913', '-71.9997597'): 16,
#  ('27.7107751', '-82.715597'): 2,
#  ('41.2636142', '-72.561779'): 14,
#  ('50.1659', '-66.3008'): 1,
#  ('42.687714', '-70.6204365'): 6,
#  ('42.1680794', '-80.1061463'): 8,
#  ('43.0573495', '-86.2540054'): 7,
#  ('24.5476307', '-81.8099928'): 2,
#  ('44.9855857', '-66.9731712'): 1,
#  ('20.7713023', '-156.2488139'): 4,
#  ('22.0749821', '-159.3171054'): 1,
#  ('48.4704175', '-122.5861359'): 1,
#  ('21.3948215', '-157.7583504'): 1,
#  ('57.4212944', '-150.1391602'): 1,
#  ('62.8167', '-92.0667'): 1,
#  ('41.9188162', '-82.6587296'): 1,
#  ('59.9945296', '-139.4726801'): 1,
#  ('47.5669131', '-122.4108696'): 26,
#  ('47.66428', '-122.41738'): 38,
#  ('41.9696182', '-82.5355364'): 95,
#  ('48.5922568', '-123.0304022'): 71,
#  ('41.7520888', '-81.2927556'): 206,
#  ('41.3014861', '-72.1119044'): 63,
#  ('47.38333', '-61.86667'): 19,
#  ('38.3044865', '-75.1076889'): 68,
#  ('48.85682', '-123.31239'): 27,
#  ('48.7267218', '-122.5645068'): 38,
#  ('49.1439869', '-125.9033203'): 31,
#  ('44.4517108', '-75.8601255'): 8,
#  ('36.9073783', '-121.8467188'): 4,
#  ('30.3466855', '-88.5519934'): 16,
#  ('37.7835456', '-76.3051217'): 50,
#  ('43.3123138', '-81.7570353'): 2,
#  ('42.6651699', '-70.7574978'): 60,
#  ('44.004715', '-76.085728'): 41,
#  ('41.7564268', '-82.6338601'): 14,
#  ('41.9551703', '-82.515564'): 119,
#  ('30.1516423', '-85.749431'): 1,
#  ('37.7394704', '-76.3091827'): 45,
#  ('41.914899', '-82.509789'): 142,
#  ('48.93767', '-123.23718'): 14,
#  ('60.3187879', '-146.689393'): 4,
#  ('44.746452', '-66.836927'): 9,
#  ('49.295688', '-123.1333065'): 26,
#  ('49.05', '-68.43333'): 19,
#  ('44.2650555', '-76.3840342'): 13,
#  ('29.7492314', '-91.7208195'): 28,
#  ('19.6482527', '-155.3710127'): 9,
#  ('45.46667', '-73.55'): 31,
#  ('46.8515043', '-54.183197'): 11,
#  ('38.9552332', '-76.5423489'): 44,
#  ('49.2912085', '-67.8939689'): 8,
#  ('39.051086', '-74.92712'): 31,
#  ('24.6342227', '-82.8564835'): 13,
#  ('42.992209', '-70.7073972'): 2,
#  ('46.4598117', '-62.0147109'): 1,
#  ('45.5231871', '-123.954277'): 13,
#  ('44.4030786', '-68.3529081'): 6,
#  ('39.4088845', '-123.810854'): 3,
#  ('45.2759253', '-66.0740325'): 5,
#  ('42.1163902', '-80.1474228'): 4,
#  ('47.661963', '-122.435841'): 38,
#  ('49.3040695', '-123.1566954'): 26,
#  ('37.1648015', '-75.9780027'): 5,
#  ('56.985867', '-135.7298748'): 5,
#  ('46.836189', '-92.0057774'): 10,
#  ('38.2775', '-74.944167'): 4,
#  ('42.5918266', '-70.6562519'): 1,
#  ('29.77242', '-93.45846'): 1,
#  ('47.4948759', '-69.9838962'): 1,
#  ('46.3299237', '-124.066932'): 1,
#  ('48.2986787', '-122.7238317'): 1,
#  ('41.5679909', '-70.5149441'): 2,
#  ('44.4441366', '-68.3189964'): 2,
#  ('40.9609698', '-124.119021'): 1,
#  ('44.1250593', '-68.7089042'): 1,
#  ('41.4759174', '-82.1756744'): 1,
#  ('20.0219909', '-155.7752591'): 1,
#  ('32.410152', '-108.47511'): 49,
#  ('42.4203', '-87.8078'): 133,
#  ('40.91051', '-73.1226536'): 14,
#  ('41.8424969', '-88.0604626'): 45,
#  ('31.85591', '-106.63955'): 10,
#  ('36.06258', '-94.1574'): 60,
#  ('45.6117531', '-76.5262699'): 2,
#  ('42.6619889', '-80.4786301'): 38,
#  ('44.1291227', '-121.3307548'): 32,
#  ('43.1196007', '-72.4555957'): 4,
#  ('40.7000158', '-124.1086006'): 2,
#  ('29.8253127', '-101.1521852'): 32,
#  ('41.2577525', '-74.7059348'): 8,
#  ('31.7310142', '-110.881319'): 91,
#  ('45.5902425', '-78.3071781'): 24,
#  ('33.2597728', '-112.8147465'): 3,
#  ('47.68333', '-68.88333'): 90,
#  ('33.0959638', '-116.9994593'): 9,
#  ('49.2713782', '-122.6675034'): 13,
#  ('35.607208', '-83.7824249'): 6,
#  ('36.0697739', '-94.1525719'): 60,
#  ('43.9770896', '-94.6318853'): 10,
#  ('42.2257209', '-82.547493'): 56,
#  ('43.716901', '-72.2774432'): 4,
#  ('25.9418086', '-81.4693308'): 37,
#  ('41.7960139', '-87.5765064'): 88,
#  ('39.2608978', '-84.738461'): 149,
#  ('45.2722702', '-93.3693771'): 13,
#  ('41.5009477', '-95.9751444'): 13,
#  ('27.8275297', '-97.0789558'): 56,
#  ('35.66591', '-75.4799'): 85,
#  ('27.0446212', '-99.4444013'): 43,
#  ('47.9988889', '-122.17'): 13,
#  ('42.2142158', '-83.7285233'): 59,
#  ('42.3508568', '-89.2367669'): 19,
#  ('42.9085938', '-70.9384632'): 52,
#  ('49.4540594', '-123.1110978'): 4,
#  ('43.150409', '-76.3769746'): 5,
#  ('43.2995889', '-73.19025'): 39,
#  ('35.75921', '-78.77902'): 13,
#  ('39.4534671', '-123.8126918'): 36,
#  ('58.4950723', '-134.7777843'): 1,
#  ('47.1308851', '-119.2861176'): 6,
#  ('35.2501716', '-91.5827289'): 45,
#  ('39.9524771', '-89.5318619'): 1,
#  ('36.2094497', '-96.2763926'): 1,
#  ('42.3217829', '-85.6906557'): 2,
#  ('45.5202893', '-73.8485876'): 32,
#  ('36.0568436', '-118.9279421'): 54,
#  ('44.4084752', '-68.2463949'): 9,
#  ('42.9389255', '-70.8008337'): 2,
#  ('43.6006167', '-88.17805'): 108,
#  ('41.2993007', '-81.1126211'): 85,
#  ('42.3452195', '-76.2989625'): 66,
#  ('37.8691452', '-87.803185'): 10,
#  ('40.7297167', '-111.840367'): 20,
#  ('47.57088', '-122.2147572'): 2,
#  ('29.8937866', '-84.3737608'): 50,
#  ('42.3576401', '-82.9866028'): 1,
#  ('40.9999066', '-72.2943732'): 1,
#  ('58.0906601', '-122.7099466'): 2,
#  ('42.5642537', '-72.3222256'): 5,
#  ('38.970328', '-78.5584005'): 36,
#  ('42.5462514', '-71.9091225'): 73,
#  ('37.047368', '-121.9310331'): 22,
#  ('32.960776', '-116.58008'): 44,
#  ('40.044253', '-105.1867721'): 102,
#  ('33.6965128', '-118.0451372'): 41,
#  ('41.1047811', '-74.4027856'): 6,
#  ('44.075562', '-92.2188091'): 5,
#  ('43.6500587', '-79.3797989'): 78,
#  ('39.47779', '-105.00754'): 17,
#  ('46.7591453', '-92.0834835'): 42,
#  ('39.3470425', '-74.7235107'): 12,
#  ('42.8580352', '-84.3438005'): 1,
#  ('34.988877', '-90.1412445'): 86,
#  ('41.6310555', '-83.1958526'): 24,
#  ('41.2551091', '-72.0271611'): 4,
#  ('44.0051', '-122.9631'): 75,
#  ('41.4274277', '-72.0552278'): 39,
#  ('34.98949', '-93.29738'): 6,
#  ('29.4241295', '-98.4935913'): 92,
#  ('44.3130401', '-78.327713'): 24,
#  ('30.6572586', '-98.0838776'): 24,
#  ('38.0627775', '-103.6097217'): 70,
#  ('53.7244433', '-101.30476'): 9,
#  ('38.9168506', '-77.0391677'): 21,
#  ('44.9080103', '-85.8956086'): 2,
#  ('43.2581433', '-85.6878448'): 68,
#  ('40.35694', '-90.01344'): 94,
#  ('43.9673067', '-77.2838402'): 3,
#  ('43.0102455', '-85.6421014'): 4,
#  ('35.80873', '-89.6269584'): 19,
#  ('44.2809728', '-69.0088177'): 1,
#  ('48.5197881', '-123.3896828'): 20,
#  ('37.250759', '-122.3110485'): 10,
#  ('35.72159', '-93.0888'): 1,
#  ('32.3946792', '-93.8269613'): 9,
#  ('46.0625', '-93.05112'): 65,
#  ('40.921673', '-72.6085088'): 5,
#  ('42.5537363', '-71.8890917'): 73,
#  ('35.7243047', '-117.8462863'): 13,
#  ('41.5359036', '-80.889'): 24,
#  ('50.904254', '-116.3707065'): 2,
#  ('41.9283', '-87.637'): 74,
#  ('38.8701106', '-85.418994'): 25,
#  ('42.4144486', '-71.2386957'): 21,
#  ('41.1708771', '-74.9145216'): 74,
#  ('40.4195733', '-74.7917891'): 33,
#  ('44.7427212', '-93.6159462'): 101,
#  ('47.5726317', '-122.4141097'): 26,
#  ('39.5348286', '-79.4826508'): 34,
#  ('39.010093', '-94.610386'): 12,
#  ('36.6252236', '-121.9317888'): 18,
#  ('47.55', '-68.91667'): 43,
#  ('45.73333', '-73.46667'): 4,
#  ('45.1178285', '-123.2391545'): 8,
#  ('30.40369', '-97.853928'): 24,
#  ('42.4928322', '-71.4726639'): 24,
#  ('44.41593', '-75.8985'): 6,
#  ('38.5957762', '-121.1795211'): 3,
#  ('38.7154685', '-78.4556437'): 28,
#  ('40.5660136', '-75.0293148'): 7,
#  ('60.78263', '-154.0238'): 4,
#  ('40.1431911', '-120.3535139'): 5,
#  ('29.6023371', '-82.3147202'): 22,
#  ('42.40083', '-76.47083'): 1,
#  ('43.6680889', '-83.9311266'): 2,
#  ('41.9225', '-88.0542'): 12,
#  ('42.9550562', '-71.5233564'): 3,
#  ('38.2648885', '-82.5819969'): 2,
#  ('31.5427632', '-110.1337928'): 2,
#  ('42.3803902', '-72.5231323'): 22,
#  ('29.4704637', '-94.6026707'): 14,
#  ('50.2417983', '-119.290452'): 15,
#  ('40.1038352', '-76.4847994'): 2,
#  ('44.6810305', '-71.4488339'): 1,
#  ('35.610977', '-105.24033'): 1,
#  ('48.9783298', '-95.7685089'): 4,
#  ('36.4903864', '-87.4405718'): 44,
#  ('39.4629689', '-105.0557327'): 60,
#  ('30.338916', '-97.836361'): 4,
#  ('44.0893', '-123.2945'): 100,
#  ('40.7803471', '-74.051154'): 1,
#  ('40.6131238', '-80.0218045'): 4,
#  ('43.5471294', '-79.5821225'): 10,
#  ('41.7205332', '-72.848386'): 31,
#  ('39.7641728', '-86.3611865'): 12,
#  ('42.5921583', '-122.819252'): 27,
#  ('32.4043133', '-80.4322815'): 3,
#  ('32.5796691', '-117.1358818'): 4,
#  ('39.26395', '-119.79832'): 3,
#  ('38.5100771', '-82.6880426'): 8,
#  ('43.7055925', '-79.2359948'): 20,
#  ('44.6065063', '-87.4347076'): 10,
#  ('43.225304', '-73.01956'): 45,
#  ('39.176333', '-120.248716'): 5,
#  ('35.716413', '-81.3565063'): 5,
#  ('42.4422078', '-87.8985214'): 64,
#  ('44.7214986', '-81.2712482'): 3,
#  ('29.5563814', '-98.6283979'): 29,
#  ('49.5058857', '-121.4209306'): 13,
#  ('37.2454985', '-76.7465844'): 6,
#  ('38.5119131', '-107.0213204'): 10,
#  ('39.0506788', '-77.0666691'): 3,
#  ('38.9528278', '-85.818655'): 75,
#  ('46.880501', '-69.8586917'): 58,
#  ('45.2236259', '-121.3847315'): 9,
#  ('41.883981', '-94.1847856'): 8,
#  ('37.5534237', '-121.5735054'): 82,
#  ('43.9666667', '-78.1666667'): 37,
#  ('44.3583523', '-78.2894003'): 1,
#  ('35.8784451', '-83.9735055'): 31,
#  ('39.0051785', '-87.2074127'): 11,
#  ('49.1086017', '-125.7852173'): 14,
#  ('40.1481761', '-97.8871536'): 3,
#  ('38.734268', '-76.069808'): 1,
#  ('42.6262777', '-84.4548655'): 3,
#  ('43.1290395', '-85.1081897'): 13,
#  ('38.0173645', '-76.8826246'): 25,
#  ('43.18061', '-87.90069'): 84,
#  ('45.91715', '-89.24433'): 7,
#  ('43.7111771', '-111.1685086'): 2,
#  ('45.9288692', '-73.495959'): 13,
#  ('45.1390063', '-66.529727'): 1,
#  ('44.49065', '-73.11097'): 7,
#  ('33.0364889', '-96.6640522'): 78,
#  ('47.4223967', '-94.0612507'): 1,
#  ('46.36068', '-69.05409'): 9,
#  ('42.8958353', '-88.78125'): 4,
#  ('31.5582317', '-106.1600068'): 3,
#  ('38.2374', '-75.25725'): 11,
#  ('32.4295707', '-93.701118'): 6,
#  ('42.8926223', '-88.3196926'): 28,
#  ('43.7141062', '-89.2543876'): 3,
#  ('39.2419444', '-83.366889'): 29,
#  ('43.0827591', '-80.7435465'): 5,
#  ('36.9065', '-76.37'): 24,
#  ('41.78981', '-69.98976'): 4,
#  ('43.0228336', '-76.3342949'): 63,
#  ('34.0616667', '-83.8675'): 18,
#  ('42.0571509', '-73.3494474'): 15,
#  ('42.5115261', '-96.4103937'): 7,
#  ('40.652046', '-79.70259'): 74,
#  ('41.9987175', '-122.6138942'): 6,
#  ('39.3731936', '-122.5662231'): 5,
#  ('39.7790361', '-86.1882248'): 44,
#  ('46.9413778', '-120.2034142'): 3,
#  ('42.6479803', '-82.4950493'): 12,
#  ('34.92484', '-81.0251'): 14,
#  ('34.7674576', '-83.9231443'): 1,
#  ('43.0051311', '-70.9475935'): 1,
#  ('50.7016766', '-119.2840576'): 27,
#  ('40.6680222', '-73.96367'): 46,
#  ('39.6949203', '-84.1560245'): 3,
#  ('35.8909075', '-106.0750352'): 2,
#  ('43.4240011', '-89.1698456'): 79,
#  ('47.3518432', '-61.8872094'): 7,
#  ('46.10226', '-120.68675'): 2,
#  ('39.2462567', '-75.1306433'): 52,
#  ('41.6413891', '-83.2405672'): 43,
#  ('38.8536119', '-75.2592659'): 11,
#  ('39.6091934', '-104.855149'): 1,
#  ('45.5142113', '-91.7324066'): 6,
#  ('47.7673829', '-108.2469606'): 8,
#  ('30.0968707', '-94.2119694'): 19,
#  ('49.36667', '-67.83333'): 12,
#  ('44.4255159', '-124.068779'): 2,
#  ('36.7644743', '-76.251642'): 6,
#  ('42.06549', '-87.67695'): 17,
#  ('42.6267913', '-70.946188'): 17,
#  ('39.120264', '-84.8116744'): 13,
#  ('39.96009', '-75.20297'): 11,
#  ('31.1580794', '-94.7970986'): 1,
#  ('44.9977642', '-74.9938774'): 16,
#  ('39.57189', '-78.48431'): 18,
#  ('35.07788', '-87.43972'): 25,
#  ('38.2289099', '-122.5980878'): 57,
#  ('45.8383091', '-121.0669126'): 12,
#  ('43.1900025', '-71.7263192'): 11,
#  ('43.7313559', '-83.975206'): 17,
#  ('38.8041373', '-77.7155491'): 17,
#  ('43.362727', '-73.0522328'): 13,
#  ('48.25', '-70.41667'): 6,
#  ('34.7348645', '-92.0525457'): 29,
#  ('40.7845001', '-73.8439026'): 2,
#  ('34.4709434', '-104.2438485'): 2,
#  ('34.899571', '-86.5668261'): 63,
#  ('29.198869', '-94.95672'): 3,
#  ('31.9164362', '-109.2737471'): 17,
#  ('40.9955281', '-81.3606892'): 2,
#  ('43.3016959', '-79.9474239'): 3,
#  ('41.3667605', '-77.9315186'): 16,
#  ('26.5498192', '-99.1661596'): 32,
#  ('40.1054769', '-79.355162'): 3,
#  ('41.672752', '-87.60939'): 57,
#  ('39.1884601', '-74.8534155'): 23,
#  ('31.5399445', '-110.7553411'): 1,
#  ('40.3627324', '-78.1579185'): 1,
#  ('42.25979', '-72.23982'): 23,
#  ('38.89511', '-77.0364'): 21,
#  ('44.6434067', '-63.2929659'): 1,
#  ('34.3930006', '-119.5140259'): 6,
#  ('48.602636', '-102.4386493'): 17,
#  ('32.873919', '-118.4416723'): 1,
#  ('33.7981711', '-84.3170106'): 70,
#  ('59.4513054', '-135.3035917'): 10,
#  ('40.2048371', '-111.6487312'): 19,
#  ('44.4847494', '-97.6007366'): 3,
#  ('36.1059911', '-89.5774823'): 1,
#  ('41.2793802', '-71.9807482'): 1,
#  ('48.6330924', '-71.7039768'): 7,
#  ('40.3242683', '-74.6630325'): 63,
#  ('50.6566667', '-107.9730556'): 2,
#  ('38.9001006', '-77.1320392'): 26,
#  ('42.0802469', '-71.9068935'): 26,
#  ('39.361351', '-86.430933'): 58,
#  ('44.3177074', '-64.2583466'): 9,
#  ('36.2579126', '-121.4261313'): 14,
#  ('39.3029227', '-74.534812'): 3,
#  ('37.0739003', '-121.9242954'): 22,
#  ('28.6439145', '-80.7165956'): 15,
#  ('44.0145694', '-79.1056437'): 1,
#  ('29.9499424', '-97.4471599'): 4,
#  ('47.0391585', '-88.5196137'): 4,
#  ('46.88333', '-70.81667'): 39,
#  ('42.5975099', '-88.4886957'): 38,
#  ('47.3817422', '-122.5504971'): 15,
#  ('49.9695517', '-98.30163'): 7,
#  ('50.41487', '-119.25074'): 46,
#  ('38.9933052', '-76.9388115'): 3,
#  ('51.0424732', '-114.761467'): 4,
#  ('42.0826493', '-71.2114692'): 15,
#  ('42.2641617', '-88.2574224'): 1,
#  ('30.5215667', '-84.2697716'): 1,
#  ('29.5412036', '-95.0118256'): 3,
#  ('36.8819048', '-121.7914402'): 18,
#  ('25.77428', '-80.19367'): 12,
#  ('44.3356036', '-111.4671439'): 59,
#  ('39.0212175', '-114.1076946'): 8,
#  ('41.634202', '-83.225434'): 61,
#  ('42.5029497', '-76.4688169'): 4,
#  ('38.9423332', '-92.3818016'): 11,
#  ('40.19533', '-88.40426'): 2,
#  ('41.24006', '-81.44063'): 28,
#  ('40.5805052', '-104.6348818'): 3,
#  ('35.8670389', '-84.0661544'): 1,
#  ('44.83269', '-116.08496'): 5,
#  ('46.8926658', '-120.796566'): 7,
#  ('48.88333', '-68.8'): 3,
#  ('39.04538', '-82.13047'): 10,
#  ('41.5653', '-85.8322'): 5,
#  ('40.0677526', '-74.4488305'): 40,
#  ('38.16067', '-75.29135'): 19,
#  ('45.6', '-75.13333'): 14,
#  ('37.1116666', '-121.9448519'): 7,
#  ('36.15399', '-95.99277'): 1,
#  ('42.92699', '-70.9439'): 52,
#  ('43.2129856', '-71.2320821'): 6,
#  ('42.0941464', '-82.4565125'): 8,
#  ('29.5420623', '-98.5008001'): 4,
#  ('33.7641774', '-94.0518308'): 3,
#  ('45.048901', '-93.1507977'): 1,
#  ('48.4888518', '-120.1615906'): 3,
#  ('42.2874689', '-83.7528992'): 35,
#  ('39.0438579', '-94.8070872'): 61,
#  ('35.590601', '-92.952625'): 32,
#  ('35.8611057', '-88.0086866'): 14,
#  ('39.571293', '-79.4088364'): 9,
#  ('39.5412714', '-82.9978108'): 19,
#  ('39.87697', '-75.212741'): 6,
#  ('41.2074598', '-95.8600044'): 2,
#  ('40.1318092', '-102.7234662'): 7,
#  ('40.9424996', '-100.1996684'): 7,
#  ('44.8139205', '-86.0671352'): 2,
#  ('36.9529441', '-122.0371413'): 5,
#  ('41.076872', '-72.4409294'): 2,
#  ('44.7320631', '-116.0784745'): 15,
#  ('48.8060615', '-71.9503008'): 9,
#  ('29.3847927', '-98.419733'): 22,
#  ('38.6034', '-78.9516'): 24,
#  ('40.1447546', '-77.050152'): 60,
#  ('50.072', '-124.972'): 10,
#  ('42.27868', '-71.15546'): 5,
#  ('40.7027822', '-104.997539'): 6,
#  ('38.4776477', '-77.150116'): 4,
#  ('37.0828451', '-121.9091892'): 8,
#  ('43.2621881', '-71.5749943'): 1,
#  ('32.25287', '-109.83162'): 16,
#  ('40.6204676', '-75.214076'): 6,
#  ('64.7', '-110.6'): 2,
#  ('48.33333', '-68.3'): 1,
#  ('26.122477', '-80.137335'): 1,
#  ('45.4170095', '-75.6980324'): 4,
#  ('37.1325058', '-122.04566'): 3,
#  ('40.3617187', '-74.7290039'): 3,
#  ('38.15877', '-75.30292'): 19,
#  ('32.1033542', '-81.0642958'): 16,
#  ('39.2549502', '-76.427498'): 12,
#  ('36.8779771', '-76.276094'): 5,
#  ('41.16116', '-79.08306'): 6,
#  ('47.688482', '-122.6753555'): 2,
#  ('45.5111589', '-73.8858032'): 32,
#  ('32.42024', '-111.05794'): 8,
#  ('45.893324', '-77.282616'): 25,
#  ('45.658594', '-73.7466554'): 2,
#  ('42.2810555', '-81.8438959'): 30,
#  ('41.7141347', '-121.5111723'): 21,
#  ('43.7031261', '-79.367981'): 1,
#  ('32.3856386', '-99.7322125'): 1,
#  ('44.8641263', '-65.0353932'): 7,
#  ('30.4004752', '-91.6754794'): 18,
#  ('41.9423188', '-86.5825653'): 5,
#  ('42.3989808', '-79.4531679'): 1,
#  ('42.0654156', '-90.1279306'): 125,
#  ('36.7197603', '-97.0236969'): 9,
#  ('39.4333425', '-76.2893093'): 1,
#  ('39.66896', '-86.19865'): 1,
#  ('40.6183378', '-74.0952006'): 1,
#  ('43.943642', '-71.700983'): 20,
#  ('48.4581005', '-71.8323029'): 32,
#  ('39.2547874', '-76.7454672'): 11,
#  ('31.3185944', '-81.5899658'): 38,
#  ('37.9751239', '-121.58638'): 1,
#  ('42.3049713', '-83.7511122'): 35,
#  ('28.5353697', '-96.9097137'): 5,
#  ('37.3697479', '-102.8601837'): 3,
#  ('42.7994371', '-84.6044147'): 2,
#  ('35.2080386', '-97.3174095'): 56,
#  ('32.4879724', '-93.745206'): 35,
#  ('44.4731835', '-81.3891563'): 26,
#  ('51.509', '-122.294'): 1,
#  ('34.3242464', '-117.8353643'): 1,
#  ('45.3', '-74.03333'): 12,
#  ('40.7588528', '-73.7607425'): 2,
#  ('38.3875835', '-82.6021535'): 1,
#  ('45.2', '-73.23333'): 48,
#  ('41.0974415', '-73.6878884'): 16,
#  ('28.5753263', '-80.9966826'): 30,
#  ('40.8054', '-74.20379'): 7,
#  ('39.16406', '-74.75074'): 9,
#  ('37.89378', '-122.26426'): 5,
#  ('42.4709573', '-72.6397991'): 22,
#  ('38.0355556', '-122.8711111'): 10,
#  ('52.6243105', '-128.4768677'): 6,
#  ('40.8528624', '-77.8271914'): 1,
#  ('33.34518', '-86.715806'): 3,
#  ('40.4742', '-95.73357'): 13,
#  ('43.062502', '-88.15625'): 1,
#  ('33.22023', '-115.56258'): 5,
#  ('39.7199625', '-85.2226639'): 7,
#  ('43.882528', '-84.3184792'): 5,
#  ('40.1186464', '-75.8430433'): 1,
#  ('36.7398', '-119.733'): 2,
#  ('48.33333', '-70.88333'): 43,
#  ('45.6902932', '-111.0463715'): 3,
#  ('31.9943919', '-85.0510883'): 50,
#  ('41.212128', '-124.00476'): 15,
#  ('31.4824413', '-81.6188908'): 2,
#  ('32.5885139', '-80.794251'): 4,
#  ('35.5124568', '-97.6681566'): 17,
#  ('46.6013956', '-90.9517336'): 12,
#  ('43.3163106', '-80.8261585'): 1,
#  ('48.71667', '-71.95'): 2,
#  ('33.1035675', '-115.7518673'): 15,
#  ('30.195414', '-103.23629'): 2,
#  ('42.03035', '-87.68347'): 9,
#  ('40.1899222', '-111.6458452'): 19,
#  ('40.7124595', '-74.50387'): 32,
#  ('44.3324439', '-120.8248901'): 4,
#  ('42.4562676', '-72.6412582'): 22,
#  ('55.3035026', '-123.1347656'): 5,
#  ('42.7791521', '-71.3479105'): 1,
#  ('39.3024721', '-119.8321818'): 6,
#  ('38.9568058', '-75.9576702'): 1,
#  ('43.0766232', '-89.4727957'): 2,
#  ('44.2422595', '-66.3873661'): 19,
#  ('46.01667', '-73.45'): 16,
#  ('45.6117724', '-93.4141297'): 29,
#  ('42.5409395', '-71.4001465'): 15,
#  ('41.2434816', '-73.307991'): 5,
#  ('41.719158', '-73.4513454'): 1,
#  ('44.4526536', '-63.724823'): 3,
#  ('38.4360624', '-82.6918278'): 3,
#  ('49.1711476', '-123.9453667'): 1,
#  ('39.2531923', '-77.2119999'): 5,
#  ('37.5154339', '-121.7452149'): 31,
#  ('48.23333', '-77.31667'): 2,
#  ('45.2875233', '-74.6345932'): 28,
#  ('41.9139665', '-88.3155727'): 5,
#  ('43.5080985', '-79.6973348'): 1,
#  ('30.8773', '-98.438'): 7,
#  ('30.4128402', '-88.4078837'): 64,
#  ('38.9826977', '-77.2316766'): 8,
#  ('36.900695', '-121.7865372'): 18,
#  ('29.8308904', '-94.0407801'): 10,
#  ('44.9791685', '-91.34375'): 1,
#  ('43.0344509', '-75.0111723'): 9,
#  ('48.2639374', '-68.7194824'): 8,
#  ('35.648683', '-120.8316278'): 11,
#  ('29.519098', '-95.2219391'): 15,
#  ('35.1925514', '-119.5750022'): 4,
#  ('31.9596995', '-110.7665634'): 2,
#  ('42.4750724', '-71.8856263'): 9,
#  ('30.5740269', '-83.9211428'): 9,
#  ('46.4035986', '-119.7238111'): 4,
#  ('35.0691344', '-118.176198'): 18,
#  ('42.8458674', '-71.0295897'): 10,
#  ('42.2068681', '-86.355688'): 7,
#  ('41.0614467', '-123.7223597'): 9,
#  ('43.489109', '-87.8806257'): 6,
#  ('45.7974478', '-88.8904036'): 11,
#  ('29.5962038', '-95.1394343'): 7,
#  ('44.7732456', '-119.6752378'): 1,
#  ('38.1606787', '-85.7809925'): 25,
#  ('47.73333', '-69.35'): 13,
#  ('37.2752991', '-107.8796234'): 7,
#  ('47.8288878', '-120.7115078'): 12,
#  ('40.326924', '-74.659066'): 63,
#  ('40.8029552', '-72.7502847'): 1,
#  ('48.46667', '-68.51667'): 8,
#  ('48.417156', '-71.9452057'): 35,
#  ('41.0548766', '-72.4689139'): 2,
#  ('41.4545746', '-70.6083241'): 29,
#  ('43.420735', '-70.5306674'): 4,
#  ('31.4892621', '-83.5359782'): 4,
#  ('49.9653504', '-98.8812721'): 1,
#  ('19.3775222', '-155.2512206'): 2,
#  ('49.1959518', '-119.7990847'): 3,
#  ('41.1411615', '-74.8455541'): 13,
#  ('39.562145', '-75.69032'): 8,
#  ('36.2123337', '-94.5263046'): 11,
#  ('44.8792839', '-91.8460253'): 1,
#  ('46.1218121', '-114.2286086'): 7,
#  ('40.3709493', '-109.3466055'): 4,
#  ('40.8429942', '-72.4762005'): 6,
#  ('26.1544661', '-97.9937553'): 1,
#  ('32.6013223', '-80.7957852'): 4,
#  ('50.5649215', '-113.6818886'): 8,
#  ('34.3625123', '-117.8654172'): 2,
#  ('38.5309118', '-121.7603159'): 16,
#  ('44.9755611', '-92.904135'): 10,
#  ('30.2638', '-84.2479'): 7,
#  ('35.097', '-97.00283'): 3,
#  ('30.2324227', '-97.7803397'): 1,
#  ('31.9072446', '-110.2207768'): 29,
#  ('37.9100288', '-119.2577559'): 2,
#  ('36.5984886', '-114.0996909'): 1,
#  ('32.5243091', '-80.2672291'): 7,
#  ('46.1598231', '-72.7551065'): 3,
#  ('39.01325', '-114.12283'): 8,
#  ('46.53333', '-75.41667'): 12,
#  ('32.84959', '-114.44713'): 12,
#  ('42.6843519', '-76.6513968'): 2,
#  ('43.1374559', '-71.6851239'): 2,
#  ('43.5251394', '-79.9982533'): 13,
#  ('45.9875901', '-84.1280544'): 24,
#  ('42.8344582', '-71.271537'): 11,
#  ('50.2656', '-119.2713'): 15,
#  ('41.6508537', '-71.5814209'): 3,
#  ('38.3374894', '-107.6384954'): 4,
#  ('41.3506044', '-76.2554082'): 12,
#  ('42.1669932', '-85.7483388'): 1,
#  ('43.4325408', '-89.7280884'): 6,
#  ('37.6789295', '-118.5939789'): 3,
#  ('39.28949', '-86.566948'): 20,
#  ('37.6778083', '-121.798175'): 5,
#  ('41.1879559', '-104.039669'): 1,
#  ('39.6372076', '-79.8132706'): 26,
#  ('40.1608963', '-103.4454592'): 12,
#  ('37.51459', '-113.2116907'): 1,
#  ('42.0421909', '-82.4848343'): 4,
#  ('39.8139381', '-76.3288956'): 33,
#  ('36.35484', '-79.66445'): 27,
#  ('29.7615461', '-82.3905945'): 1,
#  ('44.0696883', '-121.3122797'): 3,
#  ('25.3264761', '-80.7959032'): 2,
#  ('48.43333', '-68.58333'): 11,
#  ('43.116257', '-79.02928'): 8,
#  ('43.7062595', '-70.2453804'): 3,
#  ('50.669147', '-121.977895'): 2,
#  ('41.57953', '-87.8568935'): 30,
#  ('50.016667', '-95.483333'): 1,
#  ('45.8211434', '-88.1748962'): 6,
#  ('40.1004484', '-82.9013037'): 39,
#  ('43.0659721', '-71.0398293'): 9,
#  ('44.629451', '-81.271019'): 2,
#  ('33.9622825', '-98.6678874'): 4,
#  ('48.1640817', '-116.6346145'): 1,
#  ('39.24517', '-74.86948'): 10,
#  ('36.0334314', '-114.7824955'): 5,
#  ('47.8515249', '-122.8894'): 2,
#  ('40.2036571', '-105.1872253'): 15,
#  ('37.8948386', '-122.5017214'): 6,
#  ('33.0498649', '-79.3700106'): 3,
#  ('34.6687409', '-95.8963966'): 6,
#  ('42.6252', '-70.6907'): 21,
#  ('33.21841', '-98.15862'): 15,
#  ('42.1608727', '-87.9905641'): 11,
#  ('34.1663634', '-118.4820557'): 15,
#  ('39.37219', '-104.85653'): 11,
#  ('43.1260581', '-71.4494935'): 1,
#  ('34.3770694', '-118.4681726'): 6,
#  ('46.4545936', '-80.4162741'): 1,
#  ('42.2834262', '-83.378554'): 10,
#  ('48.2513057', '-122.7310824'): 2,
#  ('37.201633', '-121.99004'): 4,
#  ('30.6657861', '-83.2089686'): 8,
#  ('39.3256948', '-121.7722893'): 5,
#  ('43.6401056', '-79.4587255'): 35,
#  ('36.0928948', '-95.8932823'): 1,
#  ('29.7914746', '-82.1955872'): 1,
#  ('32.3856344', '-112.8541522'): 7,
#  ('35.1163982', '-87.2084427'): 3,
#  ('47.0217539', '-122.9035378'): 4,
#  ('34.811289', '-90.3646088'): 1,
#  ('46.1663276', '-122.9770115'): 3,
#  ('39.278826', '-86.5760422'): 20,
#  ('37.0757505', '-122.2414001'): 2,
#  ('27.2428174', '-80.9351166'): 1,
#  ('39.0517244', '-77.3446527'): 12,
#  ('42.9736526', '-70.7647414'): 2,
#  ('30.6538922', '-98.0930488'): 24,
#  ('32.464639', '-94.7263527'): 2,
#  ('46.557798', '-85.0307465'): 4,
#  ('39.164141', '-76.6625977'): 3,
#  ('37.1922538', '-93.1284428'): 31,
#  ('33.7482733', '-117.6819286'): 30,
#  ('46.1930133', '-123.1540668'): 4,
#  ('26.7294962', '-81.8611339'): 4,
#  ('48.7716', '-97.1026'): 2,
#  ('37.989779', '-78.2339001'): 18,
#  ('31.6939936', '-110.876806'): 2,
#  ('40.8538774', '-124.1329336'): 19,
#  ('38.2611314', '-121.4084959'): 25,
#  ('44.8830503', '-106.8576473'): 8,
#  ('46.6951679', '-92.7292013'): 1,
#  ('32.4170301', '-110.7250857'): 7,
#  ('46.907122', '-71.3747406'): 1,
#  ('37.6295275', '-122.4951553'): 2,
#  ('39.927904', '-111.0817793'): 1,
#  ('44.5020046', '-76.5574196'): 3,
#  ('46.6664023', '-85.6315613'): 2,
#  ('47.6078991', '-122.1534634'): 1,
#  ('36.2178949', '-88.9276743'): 1,
#  ('49.3906418', '-111.4399052'): 4,
#  ('39.7348482', '-105.5298346'): 1,
#  ('33.4352651', '-111.9057083'): 9,
#  ('46.7244487', '-123.8542682'): 3,
#  ('30.271141', '-97.7676666'): 1,
#  ('42.4704508', '-76.4505959'): 16,
#  ('36.2475', '-104.38955'): 7,
#  ('44.2806041', '-97.0463562'): 1,
#  ('44.7930436', '-91.5394592'): 3,
#  ('42.524197', '-75.53007'): 2,
#  ('47.66735', '-122.4226'): 38,
#  ('43.521411', '-119.1974008'): 3,
#  ('42.0666111', '-70.195319'): 7,
#  ('35.2626347', '-112.1513987'): 2,
#  ('37.702747', '-77.70526'): 5,
#  ('41.9050556', '-89.3468056'): 2,
#  ('40.5127877', '-75.008297'): 15,
#  ('47.7950237', '-120.7220221'): 22,
#  ('50.4673755', '-122.7056002'): 2,
#  ('35.9601021', '-95.4582825'): 1,
#  ('42.92569', '-71.0167'): 1,
#  ('38.9711459', '-76.831845'): 4,
#  ('40.0759698', '-84.6516323'): 3,
#  ('40.641305', '-81.853079'): 3,
#  ('35.1600338', '-82.8795004'): 1,
#  ('47.3025', '-122.18633'): 12,
#  ('33.7780824', '-117.7605691'): 46,
#  ('42.9325076', '-84.514432'): 2,
#  ('45.48333', '-73.6'): 19,
#  ('42.3284435', '-72.6481346'): 2,
#  ('48.5620959', '-122.9557657'): 30,
#  ('30.4112444', '-81.4206594'): 15,
#  ('45.7171718', '-88.2358093'): 1,
#  ('42.2575', '-88.9102778'): 16,
#  ('41.9441936', '-84.9840975'): 15,
#  ('61.548467', '-149.229269'): 2,
#  ('45.8799707', '-88.16185'): 6,
#  ('29.6362919', '-92.5805855'): 18,
#  ('50.3', '-64.03333'): 4,
#  ('49.7475764', '-97.1440744'): 2,
#  ('41.0718531', '-74.7911589'): 5,
#  ('33.9716108', '-86.1186808'): 5,
#  ('39.3518877', '-79.312706'): 1,
#  ('41.039341', '-75.6787872'): 10,
#  ('44.182204', '-72.5866699'): 6,
#  ('46.4954325', '-86.5511613'): 1,
#  ('33.3855863', '-112.3612976'): 3,
#  ('54.048023', '-113.3295805'): 12,
#  ('32.4950975', '-93.852085'): 2,
#  ('29.980047', '-96.293945'): 1,
#  ('35.2063', '-85.9233'): 15,
#  ('42.9402116', '-83.8086891'): 5,
#  ('37.6342177', '-97.3312283'): 1,
#  ('43.913105', '-69.8484993'): 1,
#  ('26.1377772', '-81.7853392'): 2,
#  ('42.2879872', '-83.7683267'): 35,
#  ('37.784605', '-122.5008202'): 3,
#  ('31.534147', '-97.19826'): 1,
#  ('47.66058', '-122.41483'): 38,
#  ('42.9417844', '-72.271843'): 7,
#  ('45.29463', '-64.7723'): 14,
#  ('30.100138', '-103.2575798'): 1,
#  ('49.1696217', '-119.4389391'): 8,
#  ('41.6495', '-83.2396389'): 43,
#  ('42.4765917', '-73.1575298'): 2,
#  ('42.383846', '-76.873375'): 4,
#  ('42.672966', '-84.1734619'): 1,
#  ('28.1184945', '-97.8196885'): 18,
#  ('35.09412', '-76.63996'): 12,
#  ('33.7195711', '-106.346482'): 8,
#  ('30.0074226', '-97.1575928'): 3,
#  ('32.2863365', '-110.3807488'): 17,
#  ('19.3311903', '-155.2254284'): 3,
#  ('27.8247184', '-97.057305'): 56,
#  ('37.9146801', '-122.1230203'): 6,
#  ('48.6860769', '-123.4460038'): 1,
#  ('42.6890986', '-84.4768359'): 1,
#  ('42.781006', '-87.9596'): 1,
#  ('42.854046', '-70.93761'): 10,
#  ('44.4531565', '-123.7516689'): 8,
#  ('50.291111', '-95.871944'): 1,
#  ('40.09926', '-83.11411'): 1,
#  ('41.7829909', '-120.5795002'): 1,
#  ('32.6505048', '-111.5906882'): 2,
#  ('34.78479', '-91.45843'): 4,
#  ('39.11784', '-74.79462'): 4,
#  ('40.0159146', '-105.3412485'): 3,
#  ('42.2020729', '-93.8138008'): 1,
#  ('46.6017722', '-85.2040083'): 6,
#  ('39.3138473', '-76.4881039'): 2,
#  ('43.4776189', '-79.7244573'): 2,
#  ('32.25175', '-93.46059'): 10,
#  ('48.18333', '-68.98333'): 20,
#  ('32.2062165', '-98.1552029'): 1,
#  ('43.0131555', '-91.1007439'): 2,
#  ('32.5231768', '-113.5722856'): 5,
#  ('43.1093544', '-71.5319932'): 1,
#  ('32.3155238', '-110.8168709'): 6,
#  ('39.3223661', '-82.1013412'): 33,
#  ('52.9297896', '-110.7344393'): 8,
#  ('35.4406701', '-103.4581338'): 2,
#  ('42.2445312', '-76.7793274'): 13,
#  ('35.4827062', '-98.3549738'): 7,
#  ('58.76158', '-153.27467'): 1,
#  ('43.8709517', '-70.3223705'): 9,
#  ('43.2739675', '-77.6599342'): 1,
#  ('38.5421909', '-121.6247463'): 1,
#  ('22.1221754', '-159.5640559'): 6,
#  ('49.1596587', '-109.7016123'): 2,
#  ('39.3180889', '-120.7881975'): 2,
#  ('44.9582004', '-93.2177067'): 3,
#  ('41.8372939', '-94.605075'): 5,
#  ('44.1077778', '-78.8963889'): 35,
#  ('39.183322', '-74.820024'): 23,
#  ('49.6178631', '-115.9028435'): 7,
#  ('39.0271187', '-77.6153183'): 21,
#  ('42.2905658', '-72.8078206'): 3,
#  ('41.1021052', '-87.7611923'): 17,
#  ('42.110886', '-88.1320383'): 2,
#  ('42.0855964', '-88.381123'): 8,
#  ('40.9934692', '-72.5238113'): 6,
#  ('42.9317791', '-88.033014'): 9,
#  ('31.8790427', '-109.0596485'): 8,
#  ('41.578969', '-83.149142'): 7,
#  ('45.364407', '-75.8797733'): 10,
#  ('42.1553867', '-80.0726509'): 8,
#  ('42.5332343', '-113.5392548'): 6,
#  ('45.92659', '-116.12198'): 1,
#  ('49.8476135', '-97.1320152'): 2,
#  ('48.51667', '-68.46667'): 16,
#  ('41.2819507', '-80.8338189'): 2,
#  ('40.2043887', '-75.557847'): 2,
#  ('44.3072478', '-90.569736'): 7,
#  ('38.9622452', '-74.96315'): 5,
#  ('43.6171414', '-70.2133226'): 4,
#  ('42.4820357', '-123.7261391'): 7,
#  ('41.6680392', '-87.5036144'): 8,
#  ('40.8046493', '-111.8645096'): 7,
#  ('50.6378127', '-68.7261343'): 2,
#  ('38.15613', '-75.2768'): 19,
#  ('38.5840153', '-75.0775621'): 12,
#  ('40.0329214', '-123.777144'): 5,
#  ('37.4279278', '-121.5082526'): 8,
#  ('44.29397', '-90.84834'): 1,
#  ('35.6402781', '-80.3456783'): 2,
#  ('41.2325222', '-81.5507841'): 27,
#  ('45.5', '-75.85'): 10,
#  ('33.9165829', '-98.5154343'): 4,
#  ('40.6340172', '-111.8619776'): 3,
#  ('37.4701657', '-122.3085463'): 11,
#  ('35.2177859', '-117.7593613'): 14,
#  ('39.7457589', '-104.9309363'): 4,
#  ('33.5582106', '-115.6006193'): 14,
#  ('43.5963059', '-84.9737549'): 12,
#  ('31.0505', '-87.89675'): 4,
#  ('50.6690483', '-120.5145264'): 4,
#  ('43.8864629', '-78.6780583'): 3,
#  ('42.2356778', '-88.5169952'): 4,
#  ('52.1253837', '-106.6516659'): 1,
#  ('37.3820421', '-102.0763362'): 12,
#  ('41.1565964', '-80.6322294'): 1,
#  ('44.58215', '-78.89006'): 18,
#  ('40.8566254', '-89.0252209'): 4,
#  ('40.7805414', '-98.4992981'): 9,
#  ('27.941858', '-81.0792517'): 3,
#  ('62.15472', '-145.45639'): 11,
#  ('45.6058717', '-122.8055191'): 1,
#  ('35.1376686', '-106.6874814'): 1,
#  ('40.9844711', '-72.2510937'): 4,
#  ('45.9870187', '-84.1251157'): 24,
#  ('35.0357094', '-104.6678162'): 1,
#  ('37.2009881', '-113.1570876'): 1,
#  ('45.294824', '-122.693595'): 8,
#  ('44.055414', '-87.6679748'): 14,
#  ('44.5832143', '-84.9930809'): 1,
#  ('44.675116', '-77.138789'): 1,
#  ('42.7394216', '-73.2068391'): 6,
#  ('46.9719491', '-119.2692111'): 8,
#  ('26.1962013', '-97.3921852'): 12,
#  ('48.48333', '-71.28333'): 7,
#  ('43.32', '-77.714'): 115,
#  ('30.5602839', '-97.767055'): 4,
#  ('40.8974897', '-102.6712704'): 24,
#  ('35.5220228', '-105.8770303'): 2,
#  ('41.3230722', '-71.8028641'): 5,
#  ('41.1533253', '-105.0389099'): 1,
#  ('45.4102221', '-73.930486'): 9,
#  ('44.91971', '-89.62107'): 1,
#  ('40.7036109', '-74.3047428'): 5,
#  ('45.1561438', '-85.1318743'): 2,
#  ('47.7385153', '-96.4596391'): 3,
#  ('38.4208644', '-79.0882587'): 3,
#  ('38.2985591', '-76.5637207'): 10,
#  ('55.1702408', '-118.7937927'): 7,
#  ('39.461449', '-76.5628704'): 1,
#  ('41.0084026', '-93.3280635'): 1,
#  ('41.6896', '-85.7666'): 1,
#  ('37.7510367', '-121.9765663'): 10,
#  ('34.0770681', '-106.8930041'): 1,
#  ('39.2354443', '-74.8359489'): 10,
#  ('33.0049926', '-97.1568203'): 2,
#  ('41.7893', '-91.67542'): 1,
#  ('34.1478119', '-118.1448975'): 3,
#  ('48.1120094', '-78.010118'): 9,
#  ('29.0117433', '-81.0392761'): 1,
#  ('38.3334091', '-75.325892'): 1,
#  ('47.6043997', '-117.4072838'): 3,
#  ('40.9182798', '-74.7509766'): 13,
#  ('45.8204475', '-73.929534'): 1,
#  ('42.3409035', '-72.7020049'): 1,
#  ('34.1868849', '-109.9833155'): 11,
#  ('41.0567025', '-75.0076962'): 1,
#  ('43.0574122', '-86.253233'): 7,
#  ('32.666376', '-110.6627328'): 6,
#  ('45.7806935', '-88.2249355'): 17,
#  ('47.912085', '-122.5265694'): 9,
#  ('43.1155204', '-90.2636719'): 5,
#  ('29.8085', '-101.55839'): 2,
#  ('36.1633954', '-82.1022034'): 3,
#  ('43.0558151', '-79.7687402'): 2,
#  ('55.8805801', '-119.2095028'): 9,
#  ('37.4730423', '-122.1907327'): 1,
#  ('43.3989657', '-80.36459'): 3,
#  ('41.9870217', '-82.5174858'): 69,
#  ('39.2548539', '-76.5989113'): 1,
#  ('36.4417577', '-116.8284845'): 9,
#  ('36.8113132', '-121.5823446'): 2,
#  ('40.585205', '-73.901276'): 12,
#  ('40.8344633', '-73.129769'): 22,
#  ('39.3743862', '-76.9311696'): 5,
#  ('41.9807756', '-82.5172604'): 95,
#  ('47.36667', '-70.03333'): 22,
#  ('36.4676419', '-116.3262382'): 3,
#  ('31.0289825', '-97.6065731'): 5,
#  ('41.3172223', '-72.9236412'): 8,
#  ('33.8162368', '-118.0860329'): 4,
#  ('36.1211676', '-97.1009445'): 4,
#  ('42.5243685', '-71.9717789'): 17,
#  ('40.1891988', '-74.7291756'): 18,
#  ('32.2782037', '-111.0296667'): 2,
#  ('38.092777', '-92.81824'): 6,
#  ('38.640366', '-77.23429'): 21,
#  ('38.8904984', '-122.3169923'): 7,
#  ('22.1210303', '-159.5633823'): 6,
#  ('61.1869816', '-149.8489432'): 1,
#  ('44.253391', '-76.102653'): 1,
#  ('45.4724939', '-65.8951163'): 5,
#  ('46.8244373', '-117.2091866'): 5,
#  ('47.9788', '-90.392'): 1,
#  ('40.1500131', '-97.9719543'): 2,
#  ('43.6569807', '-79.4309893'): 35,
#  ('45.6303653', '-121.9996548'): 2,
#  ('33.79516', '-100.8464227'): 10,
#  ('29.1595069', '-96.2107086'): 5,
#  ('34.2843799', '-111.3346406'): 2,
#  ('41.2251789', '-124.0547909'): 2,
#  ('43.006474', '-76.93028'): 1,
#  ('44.1025025', '-78.9326477'): 35,
#  ('42.7113215', '-70.7751872'): 1,
#  ('49.6256406', '-125.0740886'): 1,
#  ('37.7349171', '-121.9297028'): 1,
#  ('40.2965647', '-83.0696869'): 2,
#  ('42.4851373', '-74.0162659'): 1,
#  ('57.6480704', '-152.4404955'): 1,
#  ('43.048172', '-120.8001065'): 1,
#  ('40.7933617', '-77.8600235'): 2,
#  ('39.2720509', '-76.7319161'): 11,
#  ('22.1145347', '-159.5660325'): 6,
#  ('38.9322065', '-77.055316'): 2,
#  ('32.6934936', '-110.6459498'): 1,
#  ('44.4612305', '-111.4054871'): 2,
#  ('45.00664', '-79.95697'): 1,
#  ('46.3698807', '-124.0200919'): 1,
#  ('41.162748', '-81.5709382'): 1,
#  ('40.9238897', '-90.0563049'): 1,
#  ('42.3738906', '-84.1818466'): 2,
#  ('34.2766313', '-80.9919138'): 1,
#  ('42.790592', '-78.850687'): 5,
#  ('37.9243626', '-102.6116824'): 1,
#  ('53.2813694', '-131.8285101'): 1,
#  ('39.8986359', '-75.4029007'): 4,
#  ('42.341462', '-75.2478876'): 1,
#  ('40.4819921', '-74.4553328'): 1,
#  ...}

# %% [markdown]
# # All days, T

# %%
engine_path = "/Volumes/seagate-storage/db/ebird_small.db"
table_name = 'ebird_small_20190328'
lifelist_filename = 'tessa-lifelist.csv'
month = 7
day = 2
padding = 184
num_spots = 5
radius_miles = 100

tessa_scores_all = chaser(
    engine_path,
    table_name,
    lifelist_filename,
    month,
    day,
    padding,
    num_spots,
    radius_miles
)

tessa_scores_all
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
# Top spot 1: ('32.2212741', '-110.9281611')
# Number possible targets: 21
# Most common targets: ['Rufous-winged Sparrow', 'Mexican Whip-poor-will', "Botteri's Sparrow", 'Common Poorwill', 'Ladder-backed Woodpecker', 'Bridled Titmouse', "Cassin's Sparrow", 'Whiskered Screech-Owl', 'Greater Roadrunner', "Lucy's Warbler", "Scott's Oriole", "Abert's Towhee", 'Canyon Towhee', 'Black-throated Sparrow', 'Elf Owl', 'Phainopepla', 'Black-chinned Hummingbird', 'Cactus Wren', 'Arizona Woodpecker', 'Varied Bunting', 'Broad-billed Hummingbird']
#
# Top spot 2: ('31.7310142', '-110.881319')
# Number possible targets: 21
# Most common targets: ['Rufous-winged Sparrow', 'Mexican Whip-poor-will', "Botteri's Sparrow", 'Common Poorwill', 'Ladder-backed Woodpecker', 'Bridled Titmouse', "Cassin's Sparrow", 'Whiskered Screech-Owl', 'Greater Roadrunner', "Lucy's Warbler", "Scott's Oriole", "Abert's Towhee", 'Canyon Towhee', 'Black-throated Sparrow', 'Elf Owl', 'Phainopepla', 'Black-chinned Hummingbird', 'Cactus Wren', 'Arizona Woodpecker', 'Varied Bunting', 'Broad-billed Hummingbird']
#
# Top spot 3: ('31.7177294', '-110.1869364')
# Number possible targets: 21
# Most common targets: ['Rufous-winged Sparrow', 'Mexican Whip-poor-will', "Botteri's Sparrow", 'Common Poorwill', 'Ladder-backed Woodpecker', 'Bridled Titmouse', "Cassin's Sparrow", 'Whiskered Screech-Owl', 'Greater Roadrunner', "Lucy's Warbler", "Scott's Oriole", "Abert's Towhee", 'Canyon Towhee', 'Black-throated Sparrow', 'Elf Owl', 'Phainopepla', 'Black-chinned Hummingbird', 'Cactus Wren', 'Arizona Woodpecker', 'Varied Bunting', 'Broad-billed Hummingbird']
#
# Top spot 4: ('31.6445404', '-110.5958462')
# Number possible targets: 21
# Most common targets: ['Rufous-winged Sparrow', 'Mexican Whip-poor-will', "Botteri's Sparrow", 'Common Poorwill', 'Ladder-backed Woodpecker', 'Bridled Titmouse', "Cassin's Sparrow", 'Whiskered Screech-Owl', 'Greater Roadrunner', "Lucy's Warbler", "Scott's Oriole", "Abert's Towhee", 'Canyon Towhee', 'Black-throated Sparrow', 'Elf Owl', 'Phainopepla', 'Black-chinned Hummingbird', 'Cactus Wren', 'Arizona Woodpecker', 'Varied Bunting', 'Broad-billed Hummingbird']
#
# Top spot 5: ('31.3401517', '-110.9294492')
# Number possible targets: 21
# Most common targets: ['Rufous-winged Sparrow', 'Mexican Whip-poor-will', "Botteri's Sparrow", 'Common Poorwill', 'Ladder-backed Woodpecker', 'Bridled Titmouse', "Cassin's Sparrow", 'Whiskered Screech-Owl', 'Greater Roadrunner', "Lucy's Warbler", "Scott's Oriole", "Abert's Towhee", 'Canyon Towhee', 'Black-throated Sparrow', 'Elf Owl', 'Phainopepla', 'Black-chinned Hummingbird', 'Cactus Wren', 'Arizona Woodpecker', 'Varied Bunting', 'Broad-billed Hummingbird']
# {('44.5660126', '-67.056427'): 10,
#  ('42.0839551', '-70.0490427'): 8,
#  ('42.687714', '-70.6204365'): 7,
#  ('60.3413913', '-147.1028137'): 6,
#  ('42.6251904', '-70.3616729'): 8,
#  ('35.1678', '-120.69428'): 1,
#  ('52.0503333', '178.3339833'): 2,
#  ('43.8982326', '-69.4348598'): 2,
#  ('36.314222', '-121.8902827'): 1,
#  ('39.4727008', '-123.8042021'): 3,
#  ('58.3287533', '-134.6187401'): 4,
#  ('44.6156447', '-124.0665436'): 7,
#  ('57.4212944', '-150.1391602'): 1,
#  ('70.1355399', '-143.54774'): 7,
#  ('48.5922568', '-123.0304022'): 6,
#  ('70.3123202', '-148.3125114'): 11,
#  ('59.6359965', '-151.5139532'): 4,
#  ('42.992209', '-70.7073972'): 7,
#  ('32.429324', '-80.1469607'): 1,
#  ('38.3044865', '-75.1076889'): 4,
#  ('56.6521699', '-132.9288646'): 3,
#  ('30.2091599', '-88.9791107'): 4,
#  ('57.4991259', '-135.2492523'): 2,
#  ('59.9210867', '-148.0890083'): 6,
#  ('24.545713', '-81.8121761'): 4,
#  ('56.0135866', '-132.6815102'): 3,
#  ('59.5253333', '-178.4236667'): 6,
#  ('45.103577', '-67.1306705'): 10,
#  ('57.2020384', '-153.3068275'): 1,
#  ('41.3014861', '-72.1119044'): 3,
#  ('47.661963', '-122.435841'): 5,
#  ('41.4759174', '-82.1756744'): 1,
#  ('39.4088845', '-123.810854'): 3,
#  ('44.2111184', '-68.718313'): 2,
#  ('31.0706164', '-93.2111835'): 1,
#  ('44.3478561', '-121.7310423'): 4,
#  ('48.7068637', '-113.8018545'): 2,
#  ('30.8773', '-98.438'): 6,
#  ('71.3870157', '-156.4774776'): 7,
#  ('26.5498192', '-99.1661596'): 12,
#  ('39.8020431', '-105.513382'): 11,
#  ('37.8089702', '-119.5661831'): 6,
#  ('46.2529981', '-121.5115356'): 4,
#  ('36.8171698', '-111.6301489'): 2,
#  ('48.602636', '-102.4386493'): 9,
#  ('48.3446698', '-122.6696062'): 12,
#  ('31.7310142', '-110.881319'): 21,
#  ('46.0625', '-93.05112'): 2,
#  ('41.7141347', '-121.5111723'): 12,
#  ('38.586068', '-107.696981'): 1,
#  ('27.0446212', '-99.4444013'): 12,
#  ('40.8429942', '-72.4762005'): 3,
#  ('39.4607765', '-121.2835395'): 1,
#  ('33.7780824', '-117.7605691'): 7,
#  ('48.5261266', '-121.4272928'): 11,
#  ('33.8291074', '-108.6266541'): 2,
#  ('44.0893', '-123.2945'): 8,
#  ('33.0364889', '-96.6640522'): 1,
#  ('30.1041849', '-98.8038898'): 6,
#  ('40.9484721', '-111.8752277'): 1,
#  ('36.7141014', '-112.2166944'): 2,
#  ('55.9226622', '-130.0332785'): 1,
#  ('33.4352651', '-111.9057083'): 1,
#  ('29.4241295', '-98.4935913'): 5,
#  ('30.4112444', '-81.4206594'): 2,
#  ('36.0667407', '-114.807204'): 3,
#  ('44.3356036', '-111.4671439'): 2,
#  ('41.78981', '-69.98976'): 7,
#  ('27.8275297', '-97.0789558'): 1,
#  ('25.4686909', '-80.4775772'): 3,
#  ('46.8244373', '-117.2091866'): 1,
#  ('37.5534237', '-121.5735054'): 4,
#  ('48.7208672', '-120.6694722'): 10,
#  ('37.2863457', '-97.8133392'): 1,
#  ('28.9097983', '-97.5023746'): 2,
#  ('60.1127765', '-149.398613'): 4,
#  ('29.95041', '-96.25579'): 1,
#  ('37.250759', '-122.3110485'): 4,
#  ('44.0051', '-122.9631'): 7,
#  ('36.6175679', '-118.6977052'): 4,
#  ('40.044253', '-105.1867721'): 11,
#  ('48.8859802', '-118.5969583'): 1,
#  ('39.3038857', '-123.7743652'): 3,
#  ('40.466667', '-67.7'): 1,
#  ('32.2212741', '-110.9281611'): 21,
#  ('59.3335', '-178.3401667'): 6,
#  ('31.6445404', '-110.5958462'): 21,
#  ('42.34688', '-119.81294'): 2,
#  ('31.7177294', '-110.1869364'): 21,
#  ('36.4238249', '-115.3838789'): 3,
#  ('46.8926658', '-120.796566'): 5,
#  ('34.25', '-99.58333'): 1,
#  ('48.82721', '-100.44542'): 1,
#  ('25.9930992', '-97.1493988'): 3,
#  ('31.3401517', '-110.9294492'): 21,
#  ('25.77428', '-80.19367'): 3,
#  ('41.1179038', '-107.1582696'): 1,
#  ('45.731273', '-103.4423035'): 1,
#  ('40.42477', '-105.75353'): 12,
#  ('34.7678626', '-98.2882212'): 2,
#  ('44.0015513', '-69.4019544'): 2,
#  ('35.521761', '-101.75867'): 2,
#  ('38.8904984', '-122.3169923'): 4,
#  ('38.0061969', '-122.4944794'): 4,
#  ('59.4513054', '-135.3035917'): 1,
#  ('41.0793102', '-122.9388571'): 3,
#  ('41.1798168', '-105.7175732'): 6,
#  ('24.6804014', '-81.4071465'): 4,
#  ('44.00178', '-72.9296'): 1,
#  ('41.212128', '-124.00476'): 4,
#  ('44.7427212', '-93.6159462'): 1,
#  ('37.9100288', '-119.2577559'): 6,
#  ('71.38083', '-156.501'): 7,
#  ('58.4985736', '-134.8861542'): 4,
#  ('47.1790373', '-120.5909586'): 2,
#  ('36.0359891', '-106.8481923'): 3,
#  ('42.3849228', '-106.7383575'): 1,
#  ('39.6569444', '-105.2194444'): 11,
#  ('39.9879059', '-111.6983414'): 4,
#  ('48.2318198', '-121.528101'): 12,
#  ('34.7549283', '-98.3172123'): 2,
#  ('35.8854175', '-106.3228632'): 3,
#  ('34.7250677', '-118.7277552'): 2,
#  ('38.4598604', '-109.8206502'): 1,
#  ('45.1893567', '-71.1912346'): 1,
#  ('64.541256', '-165.406628'): 3,
#  ('45.91715', '-89.24433'): 1,
#  ('46.3253573', '-121.759519'): 4,
#  ('40.3763669', '-105.6520844'): 12,
#  ('37.2620023', '-107.0127205'): 1,
#  ('43.8729007', '-74.4128036'): 1,
#  ('40.5389646', '-121.6088676'): 2,
#  ('42.38253', '-119.83964'): 2,
#  ('33.8372351', '-117.7554989'): 7,
#  ('43.7141062', '-89.2543876'): 1,
#  ('40.8974897', '-102.6712704'): 1,
#  ('43.9852', '-72.9372'): 1,
#  ('37.3556519', '-113.1072922'): 4,
#  ('48.6382262', '-121.3147902'): 10,
#  ('34.8520813', '-119.1719742'): 2,
#  ('60.8127808', '-148.5804749'): 5,
#  ('44.3324439', '-120.8248901'): 4,
#  ('28.5753263', '-80.9966826'): 1,
#  ('33.6965128', '-118.0451372'): 7,
#  ('48.4862966', '-114.3537712'): 2,
#  ('39.7971944', '-111.8188477'): 4,
#  ('40.1063058', '-105.3279233'): 11,
#  ('39.4534671', '-123.8126918'): 3,
#  ('42.9736526', '-70.7647414'): 7,
#  ('32.4879724', '-93.745206'): 1,
#  ('40.0159146', '-105.3412485'): 11,
#  ('30.4128402', '-88.4078837'): 4,
#  ('43.4244873', '-114.024353'): 1,
#  ('42.9172122', '-115.8583832'): 1,
#  ('47.912085', '-122.5265694'): 9,
#  ('37.2521234', '-119.1801352'): 9,
#  ('36.15399', '-95.99277'): 1,
#  ('39.9006414', '-119.5539093'): 1,
#  ('47.7399294', '-123.4374261'): 4,
#  ('40.5055768', '-121.3536072'): 2,
#  ('35.2501716', '-91.5827289'): 2,
#  ('42.4430471', '-122.3146856'): 1,
#  ('48.865', '-121.67'): 11,
#  ('41.672752', '-87.60939'): 1,
#  ('40.8538774', '-124.1329336'): 3,
#  ('42.5332343', '-113.5392548'): 1,
#  ('47.3497293', '-114.7606341'): 1}

# %% [markdown]
# # All days, B

# %%
engine_path = "/Volumes/seagate-storage/db/ebird_small.db"
table_name = 'ebird_small_20190328'
lifelist_filename = 'bryan-lifelist.csv'
month = 7
day = 2
padding = 184
num_spots = 5
radius_miles = 100

bryan_scores_all = chaser(
    engine_path,
    table_name,
    lifelist_filename,
    month,
    day,
    padding,
    num_spots,
    radius_miles
)

bryan_scores_all
# Out:
# Top spot 1: ('44.5660126', '-67.056427')
# Number possible targets: 6
# Most common targets: ['Atlantic Puffin', 'Manx Shearwater', "Wilson's Storm-Petrel", 'Razorbill', 'Black Guillemot', 'Great Shearwater']
#
# Top spot 2: ('42.992209', '-70.7073972')
# Number possible targets: 4
# Most common targets: ["Wilson's Storm-Petrel", 'Great Shearwater', 'Roseate Tern', 'Manx Shearwater']
#
# Top spot 3: ('42.9736526', '-70.7647414')
# Number possible targets: 4
# Most common targets: ["Wilson's Storm-Petrel", 'Great Shearwater', 'Roseate Tern', 'Manx Shearwater']
#
# Top spot 4: ('42.687714', '-70.6204365')
# Number possible targets: 4
# Most common targets: ["Wilson's Storm-Petrel", 'Great Shearwater', 'Manx Shearwater', 'Roseate Tern']
#
# Top spot 5: ('42.6251904', '-70.3616729')
# Number possible targets: 4
# Most common targets: ["Wilson's Storm-Petrel", 'Great Shearwater', 'Manx Shearwater', 'Roseate Tern']
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: DeprecationWarning: Vincenty is deprecated and is going to be removed in geopy 2.0. Use `geopy.distance.geodesic` (or the default `geopy.distance.distance`) instead, which is more accurate and always converges.
# {('44.5660126', '-67.056427'): 6,
#  ('42.0839551', '-70.0490427'): 4,
#  ('42.687714', '-70.6204365'): 4,
#  ('42.6251904', '-70.3616729'): 4,
#  ('43.8982326', '-69.4348598'): 1,
#  ('57.4212944', '-150.1391602'): 1,
#  ('42.992209', '-70.7073972'): 4,
#  ('32.429324', '-80.1469607'): 1,
#  ('38.3044865', '-75.1076889'): 2,
#  ('70.3123202', '-148.3125114'): 2,
#  ('59.5253333', '-178.4236667'): 1,
#  ('41.4759174', '-82.1756744'): 1,
#  ('40.8429942', '-72.4762005'): 2,
#  ('37.5534237', '-121.5735054'): 1,
#  ('40.466667', '-67.7'): 1,
#  ('44.0893', '-123.2945'): 1,
#  ('25.77428', '-80.19367'): 1,
#  ('38.8904984', '-122.3169923'): 1,
#  ('24.6804014', '-81.4071465'): 1,
#  ('44.00178', '-72.9296'): 1,
#  ('71.38083', '-156.501'): 1,
#  ('43.8729007', '-74.4128036'): 1,
#  ('43.9852', '-72.9372'): 1,
#  ('28.5753263', '-80.9966826'): 1,
#  ('42.9736526', '-70.7647414'): 4,
#  ('37.2521234', '-119.1801352'): 1,
#  ('40.8538774', '-124.1329336'): 1}

# %%
my_scores
# Out:
# {('42.6251904', '-70.3616729'): ['Manx Shearwater',
#   "Wilson's Storm-Petrel",
#   'Pomarine Jaeger',
#   'Great Shearwater',
#   'Northern Gannet',
#   'Common Eider',
#   "Cory's Shearwater",
#   "Leach's Storm-Petrel",
#   'Parasitic Jaeger',
#   'Black-legged Kittiwake',
#   'Roseate Tern',
#   'Little Gull'],
#  ('42.687714', '-70.6204365'): ["Cory's Shearwater",
#   'Great Shearwater',
#   'Parasitic Jaeger',
#   "Wilson's Storm-Petrel",
#   'Roseate Tern',
#   'Northern Gannet',
#   'Manx Shearwater',
#   'Black-legged Kittiwake',
#   'Atlantic Puffin',
#   'Black Guillemot',
#   "Leach's Storm-Petrel",
#   'Little Gull',
#   'Common Eider',
#   'Pomarine Jaeger'],
#  ('40.00081', '-69.61919'): ['Great Shearwater', "Wilson's Storm-Petrel"],
#  ('60.3062623', '-172.1920681'): ['Short-tailed Shearwater',
#   'Northern Fulmar',
#   'Black-legged Kittiwake',
#   'Glaucous Gull',
#   'Crested Auklet'],
#  ('40.70982', '-69.4658'): ['Manx Shearwater',
#   "Cory's Shearwater",
#   "Wilson's Storm-Petrel",
#   'Great Shearwater',
#   'Long-tailed Jaeger'],
#  ('40.29131', '-69.12693'): ["Cory's Shearwater",
#   "Wilson's Storm-Petrel",
#   'Great Shearwater'],
#  ('42.0839551', '-70.0490427'): ['Manx Shearwater',
#   'Great Shearwater',
#   'Northern Gannet',
#   'Parasitic Jaeger',
#   "Wilson's Storm-Petrel",
#   "Cory's Shearwater"],
#  ('40.80457', '-69.44293'): ['Manx Shearwater',
#   "Wilson's Storm-Petrel",
#   'Great Shearwater'],
#  ('39.8751', '-69.53665'): ['Great Shearwater', "Wilson's Storm-Petrel"],
#  ('39.99024', '-68.99944'): ["Wilson's Storm-Petrel",
#   "Audubon's Shearwater",
#   'Great Shearwater'],
#  ('40.65276', '-69.35452'): ['Great Shearwater',
#   'Manx Shearwater',
#   'Red Phalarope',
#   "Wilson's Storm-Petrel"],
#  ('44.6156447', '-124.0665436'): ['Common Murre', 'Red Phalarope'],
#  ('40.00742', '-68.99939'): ["Wilson's Storm-Petrel",
#   "Audubon's Shearwater",
#   'Great Shearwater'],
#  ('41.04359', '-69.58914'): ['Great Shearwater',
#   'Manx Shearwater',
#   "Wilson's Storm-Petrel",
#   'Parasitic Jaeger'],
#  ('41.20005', '-69.68396'): ['Great Shearwater', "Wilson's Storm-Petrel"],
#  ('37.1211459', '-122.3402953'): ['Buff-breasted Sandpiper'],
#  ('31.5208333', '-80.2161111'): ['Sooty Tern',
#   "Cory's Shearwater",
#   'Bridled Tern',
#   "Audubon's Shearwater"],
#  ('38.5095795', '-74.7674561'): ["Wilson's Storm-Petrel",
#   "Audubon's Shearwater",
#   "Cory's Shearwater",
#   'South Polar Skua'],
#  ('31.8333333', '-80.3333333'): ['Bridled Tern'],
#  ('40.30519', '-69.16241'): ["Cory's Shearwater",
#   "Wilson's Storm-Petrel",
#   'Great Shearwater'],
#  ('40.46555', '-69.84608'): ['Great Shearwater'],
#  ('40.43502', '-69.20979'): ['Great Shearwater',
#   "Wilson's Storm-Petrel",
#   "Cory's Shearwater"],
#  ('39.93312', '-69.38759'): ["Wilson's Storm-Petrel", 'Great Shearwater'],
#  ('39.4727008', '-123.8042021'): ['Buff-breasted Sandpiper',
#   'Pacific Golden-Plover'],
#  ('40.56525', '-69.30376'): ["Wilson's Storm-Petrel",
#   'Manx Shearwater',
#   'Red Phalarope'],
#  ('44.104598', '-67.9150772'): ['Great Shearwater', "Wilson's Storm-Petrel"],
#  ('40.6233341', '-73.5014534'): ['American Golden-Plover',
#   'Saltmarsh Sparrow'],
#  ('31.3', '-79.8666667'): ["Audubon's Shearwater",
#   'Sooty Tern',
#   'Bridled Tern'],
#  ('32.4263402', '-78.9532471'): ['White-tailed Tropicbird'],
#  ('48.5922568', '-123.0304022'): ['Common Murre',
#   'Northwestern Crow',
#   'Marbled Murrelet',
#   'Rhinoceros Auklet',
#   'Pacific Wren',
#   'Tufted Puffin',
#   'Mew Gull',
#   'Parasitic Jaeger'],
#  ('39.4088845', '-123.810854'): ["Vaux's Swift", 'Common Murre'],
#  ('42.2594313', '-70.2831427'): ['Manx Shearwater',
#   'Great Shearwater',
#   'Northern Gannet',
#   "Wilson's Storm-Petrel",
#   'Red Phalarope'],
#  ('40.84656', '-70.11282'): ["Cory's Shearwater",
#   "Wilson's Storm-Petrel",
#   'Manx Shearwater'],
#  ('41.832863', '-124.2165756'): ['Parasitic Jaeger',
#   "Vaux's Swift",
#   'Cackling Goose'],
#  ('19.6927852', '-155.1839535'): ['Chinese Hwamei',
#   'Hawaii Elepaio',
#   'Omao',
#   'Japanese White-eye',
#   'Apapane'],
#  ('19.6482527', '-155.3710127'): ['Omao',
#   'Red-billed Leiothrix',
#   'Hawaii Amakihi',
#   'Hawaii Akepa',
#   'Akiapolaau',
#   'Kalij Pheasant',
#   'Hawaii Elepaio',
#   'Hawaii Creeper',
#   'Apapane',
#   'Yellow-fronted Canary',
#   'Hawaiian Hawk'],
#  ('42.1019161', '-70.3320265'): ['Manx Shearwater',
#   'Roseate Tern',
#   'Great Shearwater',
#   "Wilson's Storm-Petrel",
#   "Cory's Shearwater",
#   'Northern Gannet',
#   'Common Eider'],
#  ('42.992209', '-70.7073972'): ["Wilson's Storm-Petrel",
#   'Great Shearwater',
#   'Northern Gannet',
#   'Parasitic Jaeger'],
#  ('22.2072115', '-159.4754791'): ['Hawaiian Duck', 'Hawaiian Coot'],
#  ('70.1355399', '-143.54774'): ['Glaucous Gull',
#   'Common Eider',
#   'American Golden-Plover',
#   'Parasitic Jaeger',
#   'King Eider',
#   'Slaty-backed Gull',
#   'Mew Gull'],
#  ('70.3123202', '-148.3125114'): ['Glaucous Gull',
#   'King Eider',
#   'Cackling Goose',
#   'Black Guillemot',
#   'Parasitic Jaeger'],
#  ('44.4441366', '-68.3189964'): ['Black Guillemot', 'Common Eider'],
#  ('22.150861', '-159.6221217'): ['Kauai Elepaio'],
#  ('40.577', '-69.94707'): ["Wilson's Storm-Petrel", 'Great Shearwater'],
#  ('41.29177', '-69.80276'): ['Northern Gannet', "Wilson's Storm-Petrel"],
#  ('48.2986787', '-122.7238317'): ['Mew Gull'],
#  ('36.8048866', '-121.9812012'): ['Arctic Tern',
#   'Pomarine Jaeger',
#   "Buller's Shearwater",
#   'South Polar Skua',
#   'Common Murre',
#   'Black-footed Albatross',
#   'Pink-footed Shearwater',
#   'Rhinoceros Auklet',
#   'Ashy Storm-Petrel',
#   'Parasitic Jaeger',
#   'Long-tailed Jaeger'],
#  ('21.3876751', '-157.9822954'): ['Red-crested Cardinal',
#   'Common Waxbill',
#   'Pacific Golden-Plover',
#   'Japanese White-eye',
#   'Common Myna',
#   'Red-vented Bulbul',
#   'Red Avadavat',
#   'Chestnut Munia'],
#  ('40.96149', '-70.1886'): ["Wilson's Storm-Petrel"],
#  ('38.3044865', '-75.1076889'): ['Hudsonian Godwit', 'American Flamingo'],
#  ('28.6089384', '-80.8048725'): ['Common Ground-Dove'],
#  ('39.88641', '-69.40244'): ['Great Shearwater',
#   'Band-rumped Storm-Petrel',
#   "Audubon's Shearwater",
#   "Wilson's Storm-Petrel"],
#  ('46.9104643', '-124.1960621'): ['Long-tailed Jaeger',
#   'Red Phalarope',
#   "Buller's Shearwater",
#   'Short-tailed Shearwater'],
#  ('41.3014861', '-72.1119044'): ['Saltmarsh Sparrow'],
#  ('47.6185322', '-122.4102259'): ['Common Murre'],
#  ('40.69648', '-69.36254'): ['Hudsonian Godwit',
#   "Wilson's Storm-Petrel",
#   'Great Shearwater'],
#  ('38.5180863', '-74.6466064'): ['South Polar Skua'],
#  ('31.658333', '-80.4275'): ["Cory's Shearwater", 'Bridled Tern'],
#  ('40.45433', '-69.2211'): ['Great Shearwater',
#   "Wilson's Storm-Petrel",
#   "Cory's Shearwater"],
#  ('45.5231871', '-123.954277'): ['Marbled Murrelet',
#   'Buff-breasted Sandpiper'],
#  ('40.16605', '-69.08583'): ["Wilson's Storm-Petrel"],
#  ('40.06013', '-69.09985'): ["Audubon's Shearwater"],
#  ('32.7761882', '-117.2290564'): ['Fulvous Whistling-Duck',
#   'Sharp-tailed Sandpiper'],
#  ('41.4759174', '-82.1756744'): ['American Golden-Plover'],
#  ('41.0648569', '-70.0708008'): ["Cory's Shearwater"],
#  ('36.0814305', '-75.7913303'): ['Pomarine Jaeger'],
#  ('33.8372351', '-117.7554989'): ['Black-chinned Hummingbird'],
#  ('47.7950237', '-120.7220221'): ["Barrow's Goldeneye",
#   "Townsend's Warbler",
#   "Vaux's Swift"],
#  ('19.6923986', '-155.1778738'): ['Chinese Hwamei',
#   'Hawaii Elepaio',
#   'Omao',
#   'Japanese White-eye',
#   'Apapane'],
#  ('36.061034', '-107.9382706'): ["Virginia's Warbler", 'Scaled Quail'],
#  ('41.6413891', '-83.2405672'): ['American Golden-Plover'],
#  ('38.5119131', '-107.0213204'): ["MacGillivray's Warbler",
#   'Black-billed Magpie'],
#  ('40.3141441', '-105.404846'): ["Williamson's Sapsucker"],
#  ('34.8741723', '-111.7596245'): ['Greater Roadrunner'],
#  ('31.7310142', '-110.881319'): ["Bell's Vireo",
#   'Bridled Titmouse',
#   'Arizona Woodpecker',
#   'Sulphur-bellied Flycatcher',
#   'Verdin',
#   "Cassin's Sparrow",
#   'Mexican Jay',
#   'Canyon Towhee',
#   'Curve-billed Thrasher',
#   'Greater Roadrunner',
#   'Ladder-backed Woodpecker',
#   'Canyon Wren',
#   'Rock Wren',
#   "Scott's Oriole",
#   'Phainopepla',
#   'Hepatic Tanager',
#   'Varied Bunting'],
#  ('26.5498192', '-99.1661596'): ['Red-billed Pigeon',
#   'Groove-billed Ani',
#   "Couch's Kingbird",
#   'Green Jay',
#   'Ladder-backed Woodpecker',
#   'Golden-fronted Woodpecker'],
#  ('48.1947891', '-93.8032051'): ['Black-backed Woodpecker'],
#  ('39.6569444', '-105.2194444'): ['Broad-tailed Hummingbird',
#   "Woodhouse's Scrub-Jay",
#   'Canyon Wren',
#   "Virginia's Warbler",
#   'Rock Wren'],
#  ('43.8405363', '-124.1726089'): ['Pink-footed Shearwater',
#   'Fork-tailed Storm-Petrel'],
#  ('29.4704637', '-94.6026707'): ['Scissor-tailed Flycatcher'],
#  ('35.2501716', '-91.5827289'): ['Buff-breasted Sandpiper',
#   'Wood Stork',
#   'Scissor-tailed Flycatcher',
#   'American Golden-Plover'],
#  ('41.7141347', '-121.5111723'): ['Pinyon Jay',
#   'Black-billed Magpie',
#   "Williamson's Sapsucker",
#   'Gray Flycatcher',
#   'Canyon Wren',
#   'Eared Grebe',
#   "Lewis's Woodpecker"],
#  ('39.595949', '-75.2396965'): ['Buff-breasted Sandpiper'],
#  ('32.3856344', '-112.8541522'): ['Brown-crested Flycatcher',
#   'Gila Woodpecker',
#   'Cactus Wren'],
#  ('46.7591453', '-92.0834835'): ['Buff-breasted Sandpiper'],
#  ('35.66591', '-75.4799'): ['American Golden-Plover'],
#  ('33.7780824', '-117.7605691'): ['Red-crowned Parrot',
#   'California Gnatcatcher',
#   'Cactus Wren',
#   'Cinnamon Teal'],
#  ('39.5447356', '-106.2420978'): ['Pine Grosbeak'],
#  ('38.2611314', '-121.4084959'): ['Lazuli Bunting',
#   'Black-chinned Hummingbird'],
#  ('32.4295707', '-93.701118'): ['Buff-breasted Sandpiper'],
#  ('28.2018', '-81.393'): ['Limpkin'],
#  ('31.85591', '-106.63955'): ['Lark Bunting', 'Prairie Falcon'],
#  ('47.628', '-117.53239'): ['Gray Partridge'],
#  ('27.8275297', '-97.0789558'): ['Mottled Duck'],
#  ('33.3771201', '-108.9071381'): ['Lazuli Bunting'],
#  ('38.1519218', '-85.7329059'): ['Buff-breasted Sandpiper'],
#  ('41.8375089', '-88.5121168'): ['American Golden-Plover'],
#  ('32.25287', '-109.83162'): ['Cinnamon Teal', 'Chihuahuan Raven'],
#  ('40.94929', '-69.50775'): ["Wilson's Storm-Petrel"],
#  ('40.8429942', '-72.4762005'): ["Wilson's Storm-Petrel", 'Roseate Tern'],
#  ('37.1774495', '-122.1893835'): ['Western Screech-Owl'],
#  ('37.2752991', '-107.8796234'): ["Woodhouse's Scrub-Jay",
#   "Lewis's Woodpecker"],
#  ('33.10952', '-91.26201'): ['Wood Stork'],
#  ('41.4098', '-69.9869'): ['Common Eider'],
#  ('33.0959638', '-116.9994593'): ["Lawrence's Goldfinch",
#   'Common Ground-Dove'],
#  ('47.7890267', '-120.868578'): ["Townsend's Warbler", 'Black Swift'],
#  ('31.9164362', '-109.2737471'): ['Broad-tailed Hummingbird',
#   "Townsend's Warbler",
#   'Yellow-eyed Junco',
#   'Mexican Chickadee',
#   "Virginia's Warbler"],
#  ('59.4513054', '-135.3035917'): ['Varied Thrush'],
#  ('40.8538774', '-124.1329336'): ['Cinnamon Teal'],
#  ('40.044253', '-105.1867721'): ['Black-billed Magpie',
#   'Yellow-headed Blackbird',
#   'Cinnamon Teal'],
#  ('25.4686909', '-80.4775772'): ['Common Myna'],
#  ('27.0446212', '-99.4444013'): ["Morelet's Seedeater",
#   'Olive Sparrow',
#   'Common Ground-Dove',
#   "Couch's Kingbird"],
#  ('34.1868849', '-109.9833155'): ['Yellow-headed Blackbird',
#   'Cinnamon Teal',
#   "Grace's Warbler",
#   "MacGillivray's Warbler"],
#  ('30.1041849', '-98.8038898'): ['Ladder-backed Woodpecker'],
#  ('28.5353697', '-96.9097137'): ['Cave Swallow', 'Wood Stork'],
#  ('19.6444889', '-155.3237092'): ['Japanese White-eye',
#   'Omao',
#   'Hawaii Elepaio'],
#  ('28.5753263', '-80.9966826'): ['Mottled Duck',
#   'Limpkin',
#   'Common Ground-Dove'],
#  ('37.4752157', '-94.6981841'): ['Scissor-tailed Flycatcher'],
#  ('26.55474', '-97.42496'): ['Pyrrhuloxia', 'Cave Swallow'],
#  ('40.429675', '-91.5547167'): ["Bell's Vireo"],
#  ('38.2289099', '-122.5980878'): ['Pacific Golden-Plover', "Ridgway's Rail"],
#  ('21.3988971', '-157.7986908'): ['Java Sparrow',
#   'Hawaiian Coot',
#   'Japanese White-eye',
#   'Pacific Golden-Plover',
#   'Great Frigatebird',
#   'Red-vented Bulbul',
#   'Black Noddy'],
#  ('29.4241295', '-98.4935913'): ['Inca Dove',
#   'Golden-fronted Woodpecker',
#   'Scissor-tailed Flycatcher',
#   'Buff-breasted Sandpiper'],
#  ('37.8948386', '-122.5017214'): ["Ridgway's Rail"],
#  ('26.8812473', '-99.2507401'): ['Pyrrhuloxia'],
#  ('19.9682847', '-155.3212906'): ['Apapane',
#   'Hawaii Elepaio',
#   'Omao',
#   'Red-billed Leiothrix'],
#  ('46.1699049', '-107.3214483'): ['Black-billed Magpie'],
#  ('29.95041', '-96.25579'): ['Inca Dove', 'Wood Stork'],
#  ('46.0625', '-93.05112'): ['Clay-colored Sparrow'],
#  ('45.1893567', '-71.1912346'): ['Black-backed Woodpecker'],
#  ('35.0691344', '-118.176198'): ['Red-breasted Sapsucker',
#   "Lawrence's Goldfinch",
#   "MacGillivray's Warbler"],
#  ('34.6755962', '-98.615942'): ['Rock Wren', 'Black-capped Vireo'],
#  ('39.0811212', '-77.4389849'): ['American Golden-Plover'],
#  ('34.775143', '-105.544754'): ['Pinyon Jay', "Cassin's Sparrow"],
#  ('36.6252236', '-121.9317888'): ["Townsend's Warbler"],
#  ('40.6264861', '-73.4784293'): ['American Golden-Plover',
#   'Saltmarsh Sparrow'],
#  ('47.6232605', '-119.4848585'): ['Eared Grebe', 'Cinnamon Teal'],
#  ('45.2253372', '-90.853672'): ['Clay-colored Sparrow'],
#  ('26.27156', '-81.43111'): ['Common Ground-Dove'],
#  ('39.92373', '-69.00208'): ["Wilson's Storm-Petrel"],
#  ('34.3770694', '-118.4681726'): ["Costa's Hummingbird", 'Phainopepla'],
#  ('34.3930006', '-119.5140259'): ["MacGillivray's Warbler"],
#  ('41.7960139', '-87.5765064'): ['Connecticut Warbler'],
#  ('44.1291227', '-121.3307548'): ['Black-billed Magpie',
#   "MacGillivray's Warbler"],
#  ('47.3612693', '-116.7396069'): ["MacGillivray's Warbler"],
#  ('38.5838177', '-121.6354752'): ["MacGillivray's Warbler", 'Lazuli Bunting'],
#  ('30.7214731', '-92.348671'): ['Fulvous Whistling-Duck'],
#  ('31.5427632', '-110.1337928'): ['Mexican Duck',
#   'Black-throated Sparrow',
#   "Cassin's Sparrow",
#   "Lucy's Warbler",
#   'Lazuli Bunting',
#   'Gray Hawk',
#   'Tropical Kingbird'],
#  ('32.4170301', '-110.7250857'): ["Cassin's Vireo",
#   'Broad-tailed Hummingbird',
#   'Arizona Woodpecker',
#   "Rivoli's Hummingbird"],
#  ('41.212128', '-124.00476'): ['Marbled Murrelet', 'Pacific Wren'],
#  ('34.3963633', '-106.8910555'): ['Lark Bunting'],
#  ('33.07391', '-106.71396'): ['Black-chinned Sparrow',
#   "Scott's Oriole",
#   'Pinyon Jay',
#   'Rock Wren'],
#  ('41.505492', '-71.0532188'): ['Roseate Tern'],
#  ('32.9927552', '-115.5427408'): ['Black-chinned Hummingbird'],
#  ('32.4879724', '-93.745206'): ['Inca Dove'],
#  ('42.3803902', '-72.5231323'): ['American Golden-Plover'],
#  ('26.7294962', '-81.8611339'): ['Common Ground-Dove'],
#  ('45.91715', '-89.24433'): ['Northern Goshawk'],
#  ('38.0156401', '-76.1407471'): ['Buff-breasted Sandpiper'],
#  ('39.3256948', '-121.7722893'): ["MacGillivray's Warbler"],
#  ('58.5225682', '-134.8283815'): ['Mew Gull'],
#  ('40.7933617', '-77.8600235'): ['Buff-breasted Sandpiper'],
#  ('27.302613', '-80.3727579'): ['Mottled Duck']}

# %% [markdown]
# # Entire DB

# %%
assert(False) # Stop kernel from getting to here if "run all cells" is accidentally selected :P

# %%
# File to read from & number of lines to read
#data_file = '/Volumes/seagate-storage/code/ebird_data/medium_dataset.txt']
large_data_file = '/Volumes/seagate-storage/code/ebird_data/ebd_relJan-2019.txt'

# Which columns to use
desired_cols = desired_cols_chaser
                          
# Of columns, which are dates?
date_cols = ['OBSERVATION DATE']

# Chunk size to read through data_file
chunk_size = 100000

# Desired path for SQLITE db; if does not exist, will be created
engine_path = "/Volumes/seagate-storage/db/ebird_chaser.db"

# Name of SQL table
table_name = 'ebird_small_20190328'

# How many chunks to print after
# Should print ~11 times, once every 50*100000 = 50000000 lines
X = 50

engine = process_data(
    engine_path,
    large_data_file,
    desired_cols,
    date_cols,
    chunk_size,
    table_name,
    X
)

# %% [markdown]
# # Next steps
# * Test amount of time for each type of access of dataset/pandas usage/etc
# * Store entire DB (or just USA, Canada?)
# * Do chaser

# %%
def process_data(
    engine_path,
    data_path,
    desired_cols,
    date_cols,
    chunk_size,
    table_name,
    X,
    delete_old_table = True
):
    t0 = time()
    
    engine = create_engine('sqlite:///' + engine_path)
    # If database doesn't already exist, make a new engine
    if not database_exists(engine.url):
        create_database(engine.url)
    # Otherwise, make sure the engine is clear
    # Note that it's MUCH faster to delete this from filesystem directly
    elif delete_old_table:
        meta = MetaData(engine)
        meta.reflect() # Find all tables
        # Only drop the table we're trying to refill
        for tbl in reversed(meta.sorted_tables):
            if tbl.name == table_name:
                engine.execute(tbl.delete())
                print(f'Dropped table {table_name}')
        
    t1 = time()
    
    lines_saved_to_db = 0
    counter = 0

    for chunk in pd.read_csv(
        filepath_or_buffer = data_path, 
        sep = '\t',
        usecols = desired_cols.keys(),
        parse_dates = date_cols, 
        chunksize = chunk_size,
        dtype = desired_cols,
        na_values = ['X']
    ):

        chunk.to_sql(
            name = table_name,
            con = engine,
            if_exists = 'append'
        )

        # Print info every X iterations
        # i.e., every chunk_size * X lines
        lines_saved_to_db += chunk.shape[0]
        if (not counter % X):
            print(f"Iteration {counter}:")
            print(f"  Lines saved to DB: {lines_saved_to_db}") #Helpful for only saving year data
            print(f"  Minutes elapsed: {(time()-t1)/60}\n")
        counter += 1

    db_time = (time()-t1)/60
    total_time = (time()-t0)/60
    estimated_time = ((total_time-db_time) +  (577335302/lines_saved_to_db)*db_time)/60
    print(f"Total iterations: {counter}")
    print(f"Total lines saved to DB: {lines_saved_to_db}") #Helpful for only saving year data
    print(f"Minutes elapsed during DB functions: {db_time}")
    print(f"Total minutes elapsed: {total_time}")
    print(f"Estimated time for all lines: {estimated_time} hours")
    return engine
            
engine = process_data(
    engine_path,
    data_file,
    desired_cols,
    date_cols,
    chunk_size,
    table_name,
    X
)

# %% [markdown]
# ### Old code that might help with next steps

# %%
num_lines = 577335302 #from previous analysis
chunk_size = 1000000 # number of lines to read at once
num_chunks = 3 # number of chunks to test on

# %%
the_cols = [
        'Last edited date', 
        'category', 
        'common name', 
        'scientific name', 
        'observation count', 
        'country', 
        'state', 
        'latitude', 
        'longitude', 
        'observation date', 
        'observer id', 
        'protocol type',
        'ALL SPECIES REPORTED',
]

desired_cols = [item.upper() for item in the_cols]
desired_cols

# %%
just_byemeh = pd.DataFrame({'hi':[0, 1, 2], 'bye':[8, 9, 9], 'meh':[42, 42, 20]}, index=[0, 1, 2])[['bye', 'meh']]
just_byemeh.loc[just_byemeh['meh'] == 42]

just_byemeh.loc[
    (just_byemeh['meh'] == 42) & 
    (just_byemeh['bye'] == 9)]

# %%
def save_to_db(chunk, table_name, engine):
    '''
    Process & save data from chunk
    
    Processes data to identify
    
    Inputs:
        chunk: a dataframe to save
        table_name:
        engine: SQLAlchemy connection to use
    '''

    
    # For using only 2018 data:
    #only_2018 = chunk.loc[
    #    (chunk['LAST EDITED DATE'].dt.year == 2018) &
    #    (chunk['OBSERVATION DATE'].dt.year == 2018)]
    #if only_2018.shape[0]: # if this DF has anything in it (i.e. any 2018 records)
    #    only_2018.to_sql('ebird_data_2018', engine, if_exists='append')
    #return only_2018

engine = create_engine("sqlite:////Volumes/seagate-storage/db/ebird_2018.db")
if not database_exists(engine.url):
    create_database(engine.url)
    
    
    
the_cols = [
        'Last edited date', 
        'category', 
        'common name', 
        'scientific name', 
        'observation count', 
        'country', 
        'state', 
        'latitude', 
        'longitude', 
        'observation date', 
        'observer id', 
        'protocol type',
        'ALL SPECIES REPORTED',
]

desired_cols = [item.upper() for item in the_cols]
desired_cols


data_file = '/Volumes/seagate-storage/code/evil_project/example_dataset.txt' #'/Volumes/seagate-storage/code/ebird_data/ebd_relJan-2019.txt'


num_lines = 577335302 #from previous analysis
chunk_size = 1000000 # number of lines to read at once


def process(chunk):
    
    only_2018 = chunk.loc[
        (chunk['LAST EDITED DATE'].dt.year == 2018) &
        (chunk['OBSERVATION DATE'].dt.year == 2018)]
    
    if only_2018.shape[0]: # if this DF has anything in it
        only_2018.to_sql('ebird_data_2018', engine, if_exists='append')

    return only_2018

t1 = time.time()

lines_saved_to_db = 0
counter = 0

for chunk in pd.read_csv(
    data_file, 
    sep='\t', 
    #index_col = ['SAMPLING EVENT IDENTIFIER'],
    usecols = desired_cols,
    parse_dates = ['LAST EDITED DATE', 'OBSERVATION DATE'], 
    chunksize=chunk_size):
    
    '''
    '''
    
    finished_chunk = process(chunk)
    lines_saved_to_db += finished_chunk.shape[0]

    if not counter % 100:
        print(f"Iteration {counter}:")
        print(f"  Lines saved to DB: {lines_saved_to_db}")
        print(f"  Minutes elapsed: {(time.time()-t1)/60}")
    counter += 1
    
    
t2 = time.time()

process_time = t2-t1
print('Time to process rows:', process_time)

#est_time = (num_lines/(chunk_size*num_chunks))*process_time
#print('Estimated time (seconds) for all rows:', est_time)

# %% [markdown]
# Reading the whole DF:
#
# ```
# chunk_size = 1000000 # number of lines to read at once
# num_chunks = 3 # number of chunks to test on
#
# (1000000, 46)
# (1000000, 46)
# (1000000, 46)
# Time to process 3 rows: 23.173866748809814
# Estimated time for all rows: 4459.697119310624
#
#
# ---
#
# chunk_size = 3000000 # number of lines to read at once
# num_chunks = 1 # number of chunks to test on
#
# (3000000, 46)
# Time to process rows: 23.521601915359497
# Estimated time (seconds) for all rows: 4526.6170484426175
#
# ---
#
# chunk_size = 500000 # number of lines to read at once
# num_chunks = 6 # number of chunks to test on
#
# (500000, 46)
# (500000, 46)
# (500000, 46)
# (500000, 46)
# (500000, 46)
# (500000, 46)
# Time to process rows: 24.359390020370483
# Estimated time (seconds) for all rows: 4687.845264648793
# ```
#
# Reading only desired columns, with `parse_dates`
# ```
# (500000, 12)
# (500000, 12)
# (500000, 12)
# (500000, 12)
# (500000, 12)
# (500000, 12)
# Time to process rows: 13.444914102554321
# Estimated time (seconds) for all rows: 2587.407847920753
# ```
#
# Reading only desired columns, without `parse_dates`:
#
# ```
# (500000, 12)
# (500000, 12)
# (500000, 12)
# (500000, 12)
# (500000, 12)
# (500000, 12)
# Time to process rows: 11.651726961135864
# Estimated time (seconds) for all rows: 2242.3177679763053
# ```

# %%
pd.read_csv(small_data_file, sep='\t').to_sql('test_ebird_data', engine)

# %%
import pandas as pd
small_data_file = '/Volumes/seagate-storage/code/ebird_data/test_dataset.txt'
pd.read_csv(small_data_file, sep='\t').to_sql('test_ebird_data', engine)

# %% [markdown]
# # Clean up data

# %%
import time
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import pandas as pd
from functools import wraps
from time import time

# %%
small_db = pd.read_sql('test_ebird_data',con=engine)

# %%
small_db.columns

# %% [markdown]
# ### Keep only the needed columns

# %%
def timing(f):
    @wraps(f)
    def wrap(*args, **kw):
        ts = time()
        result = f(*args, **kw)
        te = time()
        print('func took: {} sec'.format(te-ts))
        return result
    return wrap


def process_chunk(chunk_df):
    new_df = chunk_df[['COMMON NAME','LATITUDE', 'LONGITUDE', 'OBSERVATION DATE']]
    new_df.to_sql('med_occ', medium_engine, if_exists='append')

@timing
def process_all_data(engine_path, data_path):
    engine = create_engine('sqlite:///'+engine_path)
    for chunk in pd.read_csv(data_path, sep='\t', chunksize=100):
        process_chunk(chunk)


process_all_data(
    engine_path='/Volumes/seagate-storage/db/large_ebird.db', 
    data_path='/Volumes/seagate-storage/code/ebird_data/large_dataset.txt')

# %%
small_database = database[['COMMON NAME','LATITUDE', 'LONGITUDE', 'OBSERVATION DATE']]
small_database
